# %% [markdown]
# ## Introduction
#
# This script demonstrates how you can use a RNN-based model to detect anomalies in timeseries data.

# %% [markdown]
# ## Setup

# %%
import os

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler


from evaluator import evaluate, compute_threshold
from dataloader import loader


# from sklearn.metrics import confusion_matrix

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "1"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"
# Out:
# 2023-02-16 14:49:00.217225: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# # Load the data
#
# We will use the SMAP data sets for training and testing.
#
# You can find raw data in https://s3-us-west-2.amazonaws.com/telemanom/data.ziphttps://s3-us-west-2.amazonaws.com/telemanom/data.zip
#
# I used preprocessed datasets with 25 dimensions.
#
# You can find preprocessed data in https://drive.google.com/drive/folders/1gisthCoE-RrKJ0j3KPV7xiibhHWT9qRmhttps://drive.google.com/drive/folders/1gisthCoE-RrKJ0j3KPV7xiibhHWT9qRm

# %%
df_train, df_test, df_test_label = loader(dataset="SMAP")

# %% [markdown]
# ## Prepare training data

# %%
# Skip data normalization because SMAP datas were already normalized.
df_train = df_train.fillna(method="ffill")
scaler = StandardScaler()
scaler.fit(df_train)
df_training_value = pd.DataFrame(scaler.transform(df_train))
df_test_value = pd.DataFrame(scaler.transform(df_test))
print("Number of training samples:", len(df_training_value))
print("Number of training samples:", len(df_test_value))
# Out:
# Number of training samples: 135183
# Number of training samples: 427617

# %% [markdown]
# ### Create sequences
# Create sequences combining `TIME_STEPS` contiguous data values from the
# training data.

# %%
TIME_STEPS = 100


# Generated training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)

# Create sequences from test values.
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)
# Out:
# Training input shape:  (135084, 100, 25)
# Test input shape:  (427518, 100, 25)

# %% [markdown]
# ## Build a model

# %%
model = keras.Sequential(
    [
        layers.InputLayer(input_shape=(x_train.shape[1], x_train.shape[2])),
        layers.GRU(64, return_sequences=True),
        layers.GRU(32),
        layers.RepeatVector(x_train.shape[1]),
        layers.GRU(32, return_sequences=True),
        layers.GRU(64),
        layers.Dense(x_train.shape[1] * x_train.shape[2]),
        layers.Reshape([x_train.shape[1], x_train.shape[2]]),
    ]
)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# 2023-02-16 14:49:03.754660: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-02-16 14:49:03.799450: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1e:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:49:03.799813: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:49:03.800143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:20:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:49:03.800466: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:21:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:49:03.800785: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 4 with properties:
# pciBusID: 0000:22:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:49:03.801104: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 5 with properties:
# pciBusID: 0000:23:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:49:03.801130: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-16 14:49:03.804019: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-16 14:49:03.804087: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-16 14:49:03.804946: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-02-16 14:49:03.805197: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-02-16 14:49:03.805932: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-02-16 14:49:03.806557: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-02-16 14:49:03.806707: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-16 14:49:03.809789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3, 4, 5
# 2023-02-16 14:49:03.810601: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-16 14:49:04.554433: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1e:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:49:04.554731: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:49:04.554982: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:20:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:49:04.555240: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:21:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:49:04.555498: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 4 with properties:
# pciBusID: 0000:22:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:49:04.555747: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 5 with properties:
# pciBusID: 0000:23:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:49:04.558445: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3, 4, 5
# 2023-02-16 14:49:04.558497: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-16 14:49:06.596739: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-02-16 14:49:06.596779: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2 3 4 5
# 2023-02-16 14:49:06.596785: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N N N N
# 2023-02-16 14:49:06.596789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N N N N
# 2023-02-16 14:49:06.596792: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N N N N
# 2023-02-16 14:49:06.596794: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 3:   N N N N N N
# 2023-02-16 14:49:06.596797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 4:   N N N N N N
# 2023-02-16 14:49:06.596800: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 5:   N N N N N N
# 2023-02-16 14:49:06.600083: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-02-16 14:49:06.600116: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22312 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1e:00.0, compute capability: 8.6)
# 2023-02-16 14:49:06.600804: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-02-16 14:49:06.600826: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 6306 MB memory) -> physical GPU (device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1f:00.0, compute capability: 8.6)
# 2023-02-16 14:49:06.601365: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-02-16 14:49:06.601383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 22312 MB memory) -> physical GPU (device: 2, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:20:00.0, compute capability: 8.6)
# 2023-02-16 14:49:06.601895: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-02-16 14:49:06.601912: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 22312 MB memory) -> physical GPU (device: 3, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:21:00.0, compute capability: 8.6)
# 2023-02-16 14:49:06.602446: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-02-16 14:49:06.602463: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:4 with 22312 MB memory) -> physical GPU (device: 4, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:22:00.0, compute capability: 8.6)
# 2023-02-16 14:49:06.602949: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-02-16 14:49:06.602965: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:5 with 22312 MB memory) -> physical GPU (device: 5, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:23:00.0, compute capability: 8.6)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 100, 64)           17472
# _________________________________________________________________
# gru_1 (GRU)                  (None, 32)                9408
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 100, 32)           0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 100, 32)           6336
# _________________________________________________________________
# gru_3 (GRU)                  (None, 64)                18816
# _________________________________________________________________
# dense (Dense)                (None, 2500)              162500
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 25)           0
# =================================================================
# Total params: 214,532
# Trainable params: 214,532
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
history = model.fit(
    x_train,
    x_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min")],
)
# Out:
# 2023-02-16 14:49:09.406900: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-02-16 14:49:09.427904: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2900000000 Hz
# Epoch 1/50
# 2023-02-16 14:49:12.350948: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-16 14:49:12.983857: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2023-02-16 14:49:13.193006: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-16 14:49:13.732345: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-16 14:49:13.732404: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 845/845 [==============================] - 28s 28ms/step - loss: 0.9857 - val_loss: 0.3951
# Epoch 2/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.9289 - val_loss: 0.3800
# Epoch 3/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.9105 - val_loss: 0.3742
# Epoch 4/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8993 - val_loss: 0.3679
# Epoch 5/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8915 - val_loss: 0.3650
# Epoch 6/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8859 - val_loss: 0.3646
# Epoch 7/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8815 - val_loss: 0.3589
# Epoch 8/50
# 845/845 [==============================] - 22s 25ms/step - loss: 0.8774 - val_loss: 0.3573
# Epoch 9/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8739 - val_loss: 0.3563
# Epoch 10/50
# 845/845 [==============================] - 22s 25ms/step - loss: 0.8710 - val_loss: 0.3572
# Epoch 11/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8681 - val_loss: 0.3537
# Epoch 12/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8657 - val_loss: 0.3538
# Epoch 13/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8641 - val_loss: 0.3530
# Epoch 14/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8617 - val_loss: 0.3525
# Epoch 15/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8607 - val_loss: 0.3496
# Epoch 16/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8589 - val_loss: 0.3504
# Epoch 17/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8578 - val_loss: 0.3498
# Epoch 18/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8567 - val_loss: 0.3480
# Epoch 19/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8559 - val_loss: 0.3473
# Epoch 20/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8547 - val_loss: 0.3468
# Epoch 21/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8544 - val_loss: 0.3466
# Epoch 22/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8530 - val_loss: 0.3492
# Epoch 23/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8524 - val_loss: 0.3465
# Epoch 24/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8517 - val_loss: 0.3463
# Epoch 25/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8511 - val_loss: 0.3456
# Epoch 26/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8503 - val_loss: 0.3472
# Epoch 27/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8499 - val_loss: 0.3463
# Epoch 28/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8492 - val_loss: 0.3448
# Epoch 29/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8487 - val_loss: 0.3449
# Epoch 30/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8483 - val_loss: 0.3448
# Epoch 31/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8476 - val_loss: 0.3443
# Epoch 32/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8472 - val_loss: 0.3452
# Epoch 33/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8467 - val_loss: 0.3441
# Epoch 34/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8464 - val_loss: 0.3436
# Epoch 35/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8461 - val_loss: 0.3434
# Epoch 36/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8455 - val_loss: 0.3441
# Epoch 37/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8449 - val_loss: 0.3441
# Epoch 38/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8449 - val_loss: 0.3438
# Epoch 39/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8446 - val_loss: 0.3435
# Epoch 40/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8439 - val_loss: 0.3432
# Epoch 41/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8439 - val_loss: 0.3423
# Epoch 42/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8435 - val_loss: 0.3426
# Epoch 43/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8430 - val_loss: 0.3430
# Epoch 44/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8433 - val_loss: 0.3423
# Epoch 45/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8425 - val_loss: 0.3423
# Epoch 46/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8427 - val_loss: 0.3423
# Epoch 47/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8421 - val_loss: 0.3422
# Epoch 48/50
# 845/845 [==============================] - 22s 25ms/step - loss: 0.8417 - val_loss: 0.3436
# Epoch 49/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8417 - val_loss: 0.3415
# Epoch 50/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8414 - val_loss: 0.3416

# %% [markdown]
# Let's plot training and validation loss to see how the training went.

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Detecting anomalies
# ### We could set threshold my using train loss, and detect which points are anomalies

# %%
# Get prediction of train data
x_train_pred = model.predict(x_train)
print("Predict train data done")

# Get test MAE loss.
x_test_pred = model.predict(x_test)
print("Predict test data done")
# Out:
# Predict train data done
# Predict test data done

# %%
thresholds = {
    "abs_mean": compute_threshold(x_train, x_train_pred, option="abs_mean"),
    "abs_median": compute_threshold(x_train, x_train_pred, option="abs_median"),
    "square_mean": compute_threshold(x_train, x_train_pred, option="square_mean"),
    "square_median": compute_threshold(x_train, x_train_pred, option="square_median"),
    "rank": compute_threshold(x_train, x_train_pred, option="rank", label=df_test_label["label"]),
}
print(f'abs mean threshold: {thresholds["abs_mean"]:.3f}')
print(f'abs median threshold: {thresholds["abs_median"]:.3f}')
print(f'square mean threshold: {thresholds["square_mean"]:.3f}')
print(f'square median threshold: {thresholds["square_median"]:.3f}')
print(f'rank threshold: {thresholds["rank"]:.3f}')

# Detect all the samples which are anomalies.
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
# anomalies = np.sum(test_mae_loss, axis=1) > threshold
# Out:
# abs mean threshold: 4.148
# abs median threshold: 3.671
# square mean threshold: 18.505
# square median threshold: 4.727
# rank threshold: 4.522

# %%
# Choose the lowest loss of the anomaly datas((# of anomalies)th) as threshold by using rank option
threshold = thresholds["square_median"]
print(f"threshold: {threshold:.3f}")

fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)

labels = df_test_label["label"].values.tolist()
dates = df_test.index


pd.DataFrame(np.sum(test_mae_loss, axis=1)).plot(ax=ax)
pd.DataFrame([threshold] * len(df_test)).plot(ax=ax)
ax.legend(["reconstruction error", "threshold"], loc="upper right")


temp_start = dates[0]
temp_date = dates[0]
temp_label = labels[0]

for xc, value in zip(dates, labels):
    if temp_label != value:
        if temp_label == True:
            ax.axvspan(temp_start, temp_date, alpha=0.2, color="orange")
        temp_start = xc
        temp_label = value
    temp_date = xc
if temp_label == True:
    ax.axvspan(temp_start, xc, alpha=0.2, color="orange")
# Out:
# threshold: 4.727

# %% [markdown]
# ## Predict & Evaluation

# %% [markdown]
# ## #1 if any included time step has anomalies => abnormal

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalies = np.sum(test_mae_loss, axis=1) > thresholds["rank"]
print("Number of anomaly samples: ", np.sum(anomalies))

anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.any(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)
print("Number of anomalous samples: ", len(anomalous_data_indices))

test_pred = np.zeros(len(df_test))
test_label = df_test_label["label"]
test_pred[anomalous_data_indices] = 1

accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  120647
# Number of anomalous samples:  193554
# accuracy: 49.30%
# precision: 8.13%
# recall: 28.77%
# f1: 12.68%

# %% [markdown]
# ## #2 If half of included time steps has anomaly => abnormal

# %%
# data i is an anomaly if ratio of anomalies sequences/involved total sequences >= 0.5
anomalies = np.sum(test_mae_loss, axis=1) > thresholds["rank"]
test_anomalies = np.zeros(len(df_test))
test_seqs = np.zeros(len(df_test))
test_label = df_test_label["label"]
print("Number of anomaly samples: ", np.sum(anomalies))

for idx, anomaly in enumerate(anomalies):
    test_seqs[idx : min(idx + TIME_STEPS, len(df_test))] += 1
    if anomaly:
        test_anomalies[idx : min(idx + TIME_STEPS, len(df_test))] += 1
test_pred_ratio = np.divide(test_anomalies, test_seqs)
test_pred = test_pred_ratio >= 0.5
print("Number of anomalous samples: ", sum(test_pred))


accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  120647
# Number of anomalous samples:  122504
# accuracy: 63.25%
# precision: 8.18%
# recall: 18.32%
# f1: 11.31%

# %%
idx = 4690
evaluation_array = [(test_seqs - test_anomalies)[idx:idx+400],
                    test_anomalies[idx:idx+400],
                    test_seqs[idx:idx+400],
                    test_pred_ratio[idx:idx+400],
                    test_pred[idx:idx+400],
                    df_test_label["label"][idx:idx+400]]

df = pd.DataFrame(evaluation_array, dtype=float)
df.index = ['Normal', 'Anomaly', '#Seq', 'Pred(%)', 'Pred', 'GT']
df.style.background_gradient(cmap='summer', axis=1)
# Out:
# <style type="text/css">
# #T_b0871_row0_col0, #T_b0871_row0_col95, #T_b0871_row0_col138, #T_b0871_row1_col196, #T_b0871_row3_col196 {
#   background-color: #349a66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col1, #T_b0871_row0_col94, #T_b0871_row0_col139, #T_b0871_row1_col195, #T_b0871_row3_col195 {
#   background-color: #369a66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col2, #T_b0871_row0_col92, #T_b0871_row0_col93, #T_b0871_row0_col140, #T_b0871_row1_col194, #T_b0871_row3_col194 {
#   background-color: #399c66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col3, #T_b0871_row0_col91, #T_b0871_row0_col141, #T_b0871_row1_col193, #T_b0871_row3_col193 {
#   background-color: #3c9e66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col4, #T_b0871_row0_col90, #T_b0871_row0_col142, #T_b0871_row1_col192, #T_b0871_row3_col192 {
#   background-color: #3e9e66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col5, #T_b0871_row0_col89, #T_b0871_row0_col143, #T_b0871_row1_col191, #T_b0871_row3_col191 {
#   background-color: #41a066;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col6, #T_b0871_row0_col88, #T_b0871_row0_col144, #T_b0871_row1_col190, #T_b0871_row3_col190 {
#   background-color: #43a166;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col7, #T_b0871_row0_col87, #T_b0871_row0_col145, #T_b0871_row1_col189, #T_b0871_row3_col189 {
#   background-color: #46a266;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col8, #T_b0871_row0_col86, #T_b0871_row0_col146, #T_b0871_row1_col188, #T_b0871_row3_col188 {
#   background-color: #49a466;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col9, #T_b0871_row0_col85, #T_b0871_row0_col147, #T_b0871_row1_col187, #T_b0871_row3_col187 {
#   background-color: #4ba566;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col10, #T_b0871_row0_col84, #T_b0871_row0_col148, #T_b0871_row1_col186, #T_b0871_row3_col186 {
#   background-color: #4ea666;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col11, #T_b0871_row0_col83, #T_b0871_row0_col149, #T_b0871_row1_col185, #T_b0871_row3_col185 {
#   background-color: #50a866;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col12, #T_b0871_row0_col81, #T_b0871_row0_col82, #T_b0871_row0_col150, #T_b0871_row1_col184, #T_b0871_row3_col184 {
#   background-color: #53a966;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col13, #T_b0871_row0_col80, #T_b0871_row0_col151, #T_b0871_row1_col183, #T_b0871_row3_col183 {
#   background-color: #56ab66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col14, #T_b0871_row0_col79, #T_b0871_row0_col152, #T_b0871_row1_col182, #T_b0871_row3_col182 {
#   background-color: #58ac66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col15, #T_b0871_row0_col77, #T_b0871_row0_col78, #T_b0871_row0_col153, #T_b0871_row1_col181, #T_b0871_row3_col181 {
#   background-color: #5bad66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col16, #T_b0871_row0_col76, #T_b0871_row0_col154, #T_b0871_row1_col180, #T_b0871_row3_col180 {
#   background-color: #5eae66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col17, #T_b0871_row0_col18, #T_b0871_row0_col19, #T_b0871_row0_col20, #T_b0871_row0_col21, #T_b0871_row0_col22, #T_b0871_row0_col23, #T_b0871_row0_col24, #T_b0871_row0_col25, #T_b0871_row0_col26, #T_b0871_row0_col27, #T_b0871_row0_col28, #T_b0871_row0_col29, #T_b0871_row0_col30, #T_b0871_row0_col31, #T_b0871_row0_col32, #T_b0871_row0_col33, #T_b0871_row0_col34, #T_b0871_row0_col35, #T_b0871_row0_col36, #T_b0871_row0_col37, #T_b0871_row0_col38, #T_b0871_row0_col39, #T_b0871_row0_col40, #T_b0871_row0_col41, #T_b0871_row0_col42, #T_b0871_row0_col43, #T_b0871_row0_col44, #T_b0871_row0_col45, #T_b0871_row0_col46, #T_b0871_row0_col47, #T_b0871_row0_col48, #T_b0871_row0_col49, #T_b0871_row0_col50, #T_b0871_row0_col51, #T_b0871_row0_col52, #T_b0871_row0_col53, #T_b0871_row0_col54, #T_b0871_row0_col55, #T_b0871_row0_col56, #T_b0871_row0_col57, #T_b0871_row0_col58, #T_b0871_row0_col59, #T_b0871_row0_col60, #T_b0871_row0_col61, #T_b0871_row0_col62, #T_b0871_row0_col63, #T_b0871_row0_col64, #T_b0871_row0_col65, #T_b0871_row0_col66, #T_b0871_row0_col67, #T_b0871_row0_col68, #T_b0871_row0_col69, #T_b0871_row0_col70, #T_b0871_row0_col71, #T_b0871_row0_col72, #T_b0871_row0_col73, #T_b0871_row0_col74, #T_b0871_row0_col75, #T_b0871_row0_col155, #T_b0871_row1_col179, #T_b0871_row3_col179 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col96, #T_b0871_row0_col137, #T_b0871_row1_col197, #T_b0871_row3_col197 {
#   background-color: #319866;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col97, #T_b0871_row0_col136, #T_b0871_row1_col198, #T_b0871_row3_col198 {
#   background-color: #2f9766;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col98, #T_b0871_row0_col135, #T_b0871_row1_col199, #T_b0871_row3_col199 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col99, #T_b0871_row0_col134, #T_b0871_row1_col200, #T_b0871_row3_col200 {
#   background-color: #299466;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col100, #T_b0871_row0_col133, #T_b0871_row1_col201, #T_b0871_row3_col201 {
#   background-color: #279366;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col101, #T_b0871_row0_col132, #T_b0871_row1_col202, #T_b0871_row3_col202 {
#   background-color: #249266;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col102, #T_b0871_row0_col131, #T_b0871_row1_col203, #T_b0871_row3_col203 {
#   background-color: #219066;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col103, #T_b0871_row0_col130, #T_b0871_row1_col204, #T_b0871_row3_col204 {
#   background-color: #1f8f66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col104, #T_b0871_row0_col129, #T_b0871_row1_col205, #T_b0871_row3_col205 {
#   background-color: #1c8e66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col105, #T_b0871_row0_col128, #T_b0871_row1_col206, #T_b0871_row3_col206 {
#   background-color: #1a8c66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col106, #T_b0871_row0_col127, #T_b0871_row1_col207, #T_b0871_row3_col207 {
#   background-color: #178b66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col107, #T_b0871_row0_col126, #T_b0871_row1_col208, #T_b0871_row3_col208 {
#   background-color: #148a66;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col108, #T_b0871_row0_col125, #T_b0871_row1_col209, #T_b0871_row3_col209 {
#   background-color: #128866;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col109, #T_b0871_row0_col124, #T_b0871_row1_col210, #T_b0871_row3_col210 {
#   background-color: #0f8766;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col110, #T_b0871_row0_col123, #T_b0871_row1_col211, #T_b0871_row3_col211 {
#   background-color: #0d8666;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col111, #T_b0871_row0_col122, #T_b0871_row1_col212, #T_b0871_row3_col212 {
#   background-color: #0a8466;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col112, #T_b0871_row0_col121, #T_b0871_row1_col213, #T_b0871_row3_col213 {
#   background-color: #078366;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col113, #T_b0871_row0_col120, #T_b0871_row1_col214, #T_b0871_row3_col214 {
#   background-color: #058266;
#   color: #f1f1f1;
# }
# #T_b0871_row0_col114, #T_b0871_row0_col118, #T_b0871_row0_col119, #T_b0871_row1_col215, #T_b0871_row1_col216, #T_b0871_row1_col217, #T_b0871_row1_col218, #T_b0871_row1_col355, #T_b0871_row1_col356, #T_b0871_row1_col357, #T_b0871_row1_col358, #T_b0871_row1_col359, #T_b0871_row1_col360, #T_b0871_row1_col361, #T_b0871_row1_col362, #T_b0871_row1_col363, #T_b0871_row1_col364, #T_b0871_row1_col365, #T_b0871_row1_col366, #T_b0871_row1_col367, #T_b0871_row1_col368, #T_b0871_row1_col369, #T_b0871_row1_col370, #T_b0871_row1_col371, #T_b0871_row1_col372, #T_b0871_row1_col373, #T_b0871_row1_col374, #T_b0871_row1_col375, #T_b0871_row1_col376, #T_b0871_row1_col377, #T_b0871_row1_col378, #T_b0871_row1_col379, #T_b0871_row1_col380, #T_b0871_row1_col381, #T_b0871_row1_col382, #T_b0871_row1_col383, #T_b0871_row1_col384, #T_b0871_row1_col385, #T_b0871_row1_col386, #T_b0871_row1_col387, #T_b0871_row1_col388, #T_b0871_row1_col389, #T_b0871_row1_col390, #T_b0871_row1_col391, #T_b0871_row1_col392, #T_b0871_row1_col393, #T_b0871_row1_col394, #T_b0871_row1_col395, #T_b0871_row1_col396, #T_b0871_row1_col397, #T_b0871_row1_col398, #T_b0871_row1_col399, #T_b0871_row3_col215, #T_b0871_row3_col216, #T_b0871_row3_col217, #T_b0871_row3_col218, #T_b0871_row3_col355, #T_b0871_row3_col356, #T_b0871_row3_col357, #T_b0871_row3_col358, #T_b0871_row3_col359, #T_b0871_row3_col360, #T_b0871_row3_col361, #T_b0871_row3_co

# %% [markdown]
# ### #3 we could find the threshold with highest f1 score by calculating all cases

# %%
from evaluator import evaluate

label = create_sequences(df_test_label["label"], TIME_STEPS)
print(label.shape)
scores = evaluate(x_test, x_test_pred, label, n=10, scoring="abs_mean")
# Out:
# (427518, 100)

# %%
# print("f1:",np.max(scores['f1']))
idx = np.argmax(scores["f1"])

print(f"threshold: {scores['thresholds'][idx]}")
print(f"precision: {scores['precision'][idx]*100:.2f}%")
print(f"recall: {scores['recall'][idx]*100:.2f}%")
print(f"f1: {scores['f1'][idx]*100:.2f}%")
# Out:
# threshold: 0.0
# precision: 14.35%
# recall: 100.00%
# f1: 25.09%
