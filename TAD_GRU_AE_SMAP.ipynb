# %% [markdown]
# ## Introduction
#
# This script demonstrates how you can use a RNN-based model to detect anomalies in timeseries data.

# %% [markdown]
# ## Setup

# %%
import os
import random

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers

from dataloader import loader
from evaluator import compute_threshold, evaluate

# from sklearn.metrics import confusion_matrix

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# 2023-02-21 23:07:58.918639: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# # Load the data

# %%
df_train, df_test, df_test_label = loader(dataset="SMAP")

# %% [markdown]
# ## Prepare training data

# %%
# Skip data normalization because SMAP datas were already normalized.
df_train = df_train.fillna(method="ffill")
scaler = StandardScaler()
scaler.fit(df_train)
df_training_value = pd.DataFrame(scaler.transform(df_train))
df_test_value = pd.DataFrame(scaler.transform(df_test))
print("Number of training samples:", len(df_training_value))
print("Number of training samples:", len(df_test_value))
# Out:
# Number of training samples: 135183
# Number of training samples: 427617

# %% [markdown]
# ### Create sequences
# Create sequences combining `TIME_STEPS` contiguous data values from the
# training data.

# %%
TIME_STEPS = 100


# Generated training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)

# Create sequences from test values.
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)
# Out:
# Training input shape:  (135084, 100, 25)
# Test input shape:  (427518, 100, 25)

# %% [markdown]
# ## Build a model

# %%
model = keras.Sequential(
    [
        layers.InputLayer(input_shape=(x_train.shape[1], x_train.shape[2])),
        layers.GRU(64, return_sequences=True),
        layers.GRU(32),
        layers.RepeatVector(x_train.shape[1]),
        layers.GRU(32, return_sequences=True),
        layers.GRU(64),
        layers.Dense(x_train.shape[1] * x_train.shape[2]),
        layers.Reshape([x_train.shape[1], x_train.shape[2]]),
    ]
)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# 2023-02-21 23:08:02.505346: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-02-21 23:08:02.551739: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-21 23:08:02.551794: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-21 23:08:02.555447: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-21 23:08:02.555563: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-21 23:08:02.556449: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-02-21 23:08:02.556731: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-02-21 23:08:02.557445: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-02-21 23:08:02.558065: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-02-21 23:08:02.558233: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-21 23:08:02.558817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-02-21 23:08:02.559191: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-21 23:08:02.562875: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-21 23:08:02.563948: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-02-21 23:08:02.564035: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-21 23:08:03.099820: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-02-21 23:08:03.099870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-02-21 23:08:03.099876: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-02-21 23:08:03.101311: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-02-21 23:08:03.101349: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22312 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1f:00.0, compute capability: 8.6)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 100, 64)           17472
# _________________________________________________________________
# gru_1 (GRU)                  (None, 32)                9408
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 100, 32)           0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 100, 32)           6336
# _________________________________________________________________
# gru_3 (GRU)                  (None, 64)                18816
# _________________________________________________________________
# dense (Dense)                (None, 2500)              162500
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 25)           0
# =================================================================
# Total params: 214,532
# Trainable params: 214,532
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
history = model.fit(
    x_train,
    x_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min")],
)
# Out:
# 2023-02-21 23:08:06.867193: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-02-21 23:08:06.887870: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2900000000 Hz
# Epoch 1/50
# 2023-02-21 23:08:10.017585: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-21 23:08:10.690720: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2023-02-21 23:08:10.881119: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-21 23:08:11.398421: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-21 23:08:11.398486: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 845/845 [==============================] - 28s 27ms/step - loss: 0.9888 - val_loss: 0.3958
# Epoch 2/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.9288 - val_loss: 0.3801
# Epoch 3/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.9104 - val_loss: 0.3739
# Epoch 4/50
# 845/845 [==============================] - 22s 26ms/step - loss: 0.8990 - val_loss: 0.3673
# Epoch 5/50
# 845/845 [==============================] - 22s 25ms/step - loss: 0.8912 - val_loss: 0.3638
# Epoch 6/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8850 - val_loss: 0.3601
# Epoch 7/50
# 845/845 [==============================] - 22s 25ms/step - loss: 0.8803 - val_loss: 0.3583
# Epoch 8/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8760 - val_loss: 0.3565
# Epoch 9/50
# 845/845 [==============================] - 22s 25ms/step - loss: 0.8726 - val_loss: 0.3572
# Epoch 10/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8693 - val_loss: 0.3536
# Epoch 11/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8669 - val_loss: 0.3520
# Epoch 12/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8644 - val_loss: 0.3515
# Epoch 13/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8627 - val_loss: 0.3508
# Epoch 14/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8613 - val_loss: 0.3531
# Epoch 15/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8593 - val_loss: 0.3496
# Epoch 16/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8584 - val_loss: 0.3499
# Epoch 17/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8568 - val_loss: 0.3475
# Epoch 18/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8557 - val_loss: 0.3485
# Epoch 19/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8547 - val_loss: 0.3473
# Epoch 20/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8537 - val_loss: 0.3460
# Epoch 21/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8528 - val_loss: 0.3460
# Epoch 22/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8519 - val_loss: 0.3458
# Epoch 23/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8512 - val_loss: 0.3455
# Epoch 24/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8507 - val_loss: 0.3451
# Epoch 25/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8497 - val_loss: 0.3450
# Epoch 26/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8495 - val_loss: 0.3464
# Epoch 27/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8487 - val_loss: 0.3451
# Epoch 28/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8481 - val_loss: 0.3446
# Epoch 29/50
# 845/845 [==============================] - 21s 24ms/step - loss: 0.8476 - val_loss: 0.3448
# Epoch 30/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8474 - val_loss: 0.3445
# Epoch 31/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8469 - val_loss: 0.3444
# Epoch 32/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8463 - val_loss: 0.3436
# Epoch 33/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8462 - val_loss: 0.3438
# Epoch 34/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8457 - val_loss: 0.3439
# Epoch 35/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8453 - val_loss: 0.3438
# Epoch 36/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8448 - val_loss: 0.3432
# Epoch 37/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8452 - val_loss: 0.3430
# Epoch 38/50
# 845/845 [==============================] - 21s 24ms/step - loss: 0.8441 - val_loss: 0.3442
# Epoch 39/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8440 - val_loss: 0.3427
# Epoch 40/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8437 - val_loss: 0.3428
# Epoch 41/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8438 - val_loss: 0.3431
# Epoch 42/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8433 - val_loss: 0.3427
# Epoch 43/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8431 - val_loss: 0.3443
# Epoch 44/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8426 - val_loss: 0.3422
# Epoch 45/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8426 - val_loss: 0.3429
# Epoch 46/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8422 - val_loss: 0.3424
# Epoch 47/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8421 - val_loss: 0.3416
# Epoch 48/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8420 - val_loss: 0.3417
# Epoch 49/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8415 - val_loss: 0.3419
# Epoch 50/50
# 845/845 [==============================] - 21s 25ms/step - loss: 0.8416 - val_loss: 0.3419

# %% [markdown]
# Let's plot training and validation loss to see how the training went.

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Detecting anomalies
# ### We could set threshold my using train loss, and detect which points are anomalies

# %%
# Get prediction of train data
x_train_pred = model.predict(x_train)
print("Predict train data done")

# Get test MAE loss.
x_test_pred = model.predict(x_test)
print("Predict test data done")
# Out:
# Predict train data done
# Predict test data done

# %%
thresholds = {
    "abs_mean": compute_threshold(x_train, x_train_pred, option="abs_mean"),
    "abs_median": compute_threshold(x_train, x_train_pred, option="abs_median"),
    "abs_max": compute_threshold(x_train, x_train_pred, option="abs_max"),
    "square_mean": compute_threshold(x_train, x_train_pred, option="square_mean"),
    "square_median": compute_threshold(x_train, x_train_pred, option="square_median"),
    "rank": compute_threshold(x_train, x_train_pred, option="rank", label=df_test_label["label"]),
}
print(f'abs mean threshold: {thresholds["abs_mean"]:.3f}')
print(f'abs median threshold: {thresholds["abs_median"]:.3f}')
print(f'abs max threshold: {thresholds["abs_max"]:.3f}')
print(f'square mean threshold: {thresholds["square_mean"]:.3f}')
print(f'square median threshold: {thresholds["square_median"]:.3f}')
print(f'rank threshold: {thresholds["rank"]:.3f}')

# Detect all the samples which are anomalies.
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
# Out:
# abs mean threshold: 4.165
# abs median threshold: 3.664
# abs max threshold: 42.462
# square mean threshold: 18.512
# square median threshold: 4.785
# rank threshold: 4.497

# %%
# Choose the lowest loss of the anomaly datas((# of anomalies)th) as threshold by using rank option
threshold = thresholds["square_median"]
print(f"threshold: {threshold:.3f}")

fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)

labels = df_test_label["label"].values.tolist()
dates = df_test.index


pd.DataFrame(np.sum(test_mae_loss, axis=1)).plot(ax=ax)
pd.DataFrame([threshold] * len(df_test)).plot(ax=ax)
ax.legend(["reconstruction error", "threshold"], loc="upper right")


temp_start = dates[0]
temp_date = dates[0]
temp_label = labels[0]

for xc, value in zip(dates, labels):
    if temp_label != value:
        if temp_label == True:
            ax.axvspan(temp_start, temp_date, alpha=0.2, color="orange")
        temp_start = xc
        temp_label = value
    temp_date = xc
if temp_label == True:
    ax.axvspan(temp_start, xc, alpha=0.2, color="orange")
# Out:
# threshold: 4.785

# %% [markdown]
# ## Predict & Evaluation

# %% [markdown]
# ## #1 if any included time step has anomalies => abnormal

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalies = np.sum(test_mae_loss, axis=1) > thresholds["rank"]
print("Number of anomaly samples: ", np.sum(anomalies))

anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.any(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)
print("Number of anomalous samples: ", len(anomalous_data_indices))

test_pred = np.zeros(len(df_test))
test_label = df_test_label["label"]
test_pred[anomalous_data_indices] = 1

accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  121503
# Number of anomalous samples:  196811
# accuracy: 48.67%
# precision: 8.13%
# recall: 29.27%
# f1: 12.73%

# %% [markdown]
# ## #2 If half of included time steps has anomaly => abnormal

# %%
# data i is an anomaly if ratio of anomalies sequences/involved total sequences >= 0.5
anomalies = np.sum(test_mae_loss, axis=1) > thresholds["rank"]
test_anomalies = np.zeros(len(df_test))
test_seqs = np.zeros(len(df_test))
test_label = df_test_label["label"]
print("Number of anomaly samples: ", np.sum(anomalies))

for idx, anomaly in enumerate(anomalies):
    test_seqs[idx : min(idx + TIME_STEPS, len(df_test))] += 1
    if anomaly:
        test_anomalies[idx : min(idx + TIME_STEPS, len(df_test))] += 1
test_pred_ratio = np.divide(test_anomalies, test_seqs)
test_pred = test_pred_ratio >= 0.5
print("Number of anomalous samples: ", sum(test_pred))


accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  121503
# Number of anomalous samples:  123190
# accuracy: 63.11%
# precision: 8.17%
# recall: 18.40%
# f1: 11.31%

# %%
idx = 4690
evaluation_array = [(test_seqs - test_anomalies)[idx:idx+400],
                    test_anomalies[idx:idx+400],
                    test_seqs[idx:idx+400],
                    test_pred_ratio[idx:idx+400],
                    test_pred[idx:idx+400],
                    df_test_label["label"][idx:idx+400]]

df = pd.DataFrame(evaluation_array, dtype=float)
df.index = ['Normal', 'Anomaly', '#Seq', 'Pred(%)', 'Pred', 'GT']
df.style.background_gradient(cmap='summer', axis=1)
# Out:
# <style type="text/css">
# #T_99208_row0_col0, #T_99208_row0_col100, #T_99208_row0_col134, #T_99208_row1_col206, #T_99208_row3_col206 {
