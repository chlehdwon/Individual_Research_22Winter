# %% [markdown]
# ## Introduction
#
# This script demonstrates how you can use a RNN-based model to detect anomalies in timeseries data.

# %% [markdown]
# ## Setup

# %%
import os
import random

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import backend as K
from sklearn.preprocessing import StandardScaler

from evaluator import evaluate, compute_threshold
from dataloader import loader


os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# 2023-02-23 02:28:40.149526: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# # Load the data
#
# We will use the SMAP data sets for training and testing.
#
# You can find raw data in https://s3-us-west-2.amazonaws.com/telemanom/data.ziphttps://s3-us-west-2.amazonaws.com/telemanom/data.zip
#
# I used preprocessed datasets with 25 dimensions.
#
# You can find preprocessed data in https://drive.google.com/drive/folders/1gisthCoE-RrKJ0j3KPV7xiibhHWT9qRmhttps://drive.google.com/drive/folders/1gisthCoE-RrKJ0j3KPV7xiibhHWT9qRm

# %%
df_train, df_test, df_test_label = loader(dataset="UCR")

# %% [markdown]
# ## Prepare training data

# %%
# Skip data normalization because SMAP datas were already normalized.
df_train = df_train.fillna(method="ffill")
scaler = StandardScaler()
scaler.fit(df_train)
df_training_value = pd.DataFrame(scaler.transform(df_train))
df_test_value = pd.DataFrame(scaler.transform(df_test))
print("Number of training samples:", len(df_training_value))
print("Number of training samples:", len(df_test_value))
# Out:
# Number of training samples: 35000
# Number of training samples: 44795

# %% [markdown]
# ### Create sequences
# Create sequences combining `TIME_STEPS` contiguous data values from the
# training data.

# %%
TIME_STEPS = 100


# Generated training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)

# Create sequences from test values.
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)
# Out:
# Training input shape:  (34901, 100, 1)
# Test input shape:  (44696, 100, 1)

# %% [markdown]
# ## Build a model

# %%
class Sampling(layers.Layer):
    def __init__(self, name="sampling"):
        super(Sampling, self).__init__(name=name)

    def call(self, inputs):
        mu, logvar = inputs
        batch, dim = tf.shape(mu)[0], tf.shape(mu)[1]
        sigma = K.exp(logvar * 0.5)
        epsilon = K.random_normal(shape=(batch, dim), mean=0.0, stddev=1.0)

        return mu + sigma * epsilon

# %%
class Encoder(keras.Model):
    def __init__(self, time_step, x_dim, h1_dim, h2_dim, z_dim, name="encoder", **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)
        self.encoder_inputs = keras.Input(shape=(time_step, x_dim))
        self.encoder_lstm1 = layers.LSTM(h1_dim, name="encoder_lstm1", return_sequences="True")
        self.encoder_lstm2 = layers.LSTM(h2_dim, name="encoder_lstm2")
        self.z_mean = layers.Dense(z_dim, name="z_mean")
        self.z_var = layers.Dense(z_dim, name="z_var")
        self.z_sample = Sampling()

    def call(self, inputs):
        self.encoder_inputs = inputs  # (None, time_steps, x_dim)
        hidden1 = self.encoder_lstm1(self.encoder_inputs)  # (None, time_steps, h1_dim)
        hidden = self.encoder_lstm2(hidden1)  # (None, h2_dim)
        mu_z = self.z_mean(hidden)  # (None, z_dim)
        logvar_z = self.z_var(hidden)  # (None, z_dim)
        z = self.z_sample((mu_z, logvar_z))  # (batch, z_dim)

        return mu_z, logvar_z, z

# %%
class Decoder(keras.Model):
    def __init__(self, time_step, x_dim, h1_dim, h2_dim, z_dim, name="decoder", **kwargs):
        super(Decoder, self).__init__(name=name, **kwargs)
        self.decoder_inputs = layers.RepeatVector(time_step, name="repeat_vector")
        self.decoder_lstm1 = layers.LSTM(h2_dim, name="decoder_lstm1", return_sequences="True")
        self.decoder_lstm2 = layers.LSTM(h1_dim, name="decoder_lstm2")
        self.dense = layers.Dense(x_dim * time_step, name="decoder_dense")
        self.reshape = layers.Reshape([time_step, x_dim], name="decoder_reshape")

    def call(self, inputs):
        z = self.decoder_inputs(inputs)  # (None, time_step, z_dim)
        hidden1 = self.decoder_lstm1(z)  # (None, time_step, h2_dim)
        hidden = self.decoder_lstm2(hidden1)  # (None, h1_dim)
        flatten = self.dense(hidden)  # (None, time_step * x_dim)
        reconstructed_x = self.reshape(flatten)  # (None, time_step, x_dim)

        return reconstructed_x

# %%
class LSTM_VAE(keras.Model):
    def __init__(self, time_step, x_dim, h1_dim, h2_dim, z_dim, name="lstm_vae", **kwargs):
        super(LSTM_VAE, self).__init__(name=name, **kwargs)

        self.encoder = Encoder(time_step, x_dim, h1_dim, h2_dim, z_dim, **kwargs)
        self.decoder = Decoder(time_step, x_dim, h1_dim, h2_dim, z_dim, **kwargs)
        self.total_loss = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss = keras.metrics.Mean(name="kl_loss")

    def reconstruct_loss(self, x, reconst_x):
        reconst_loss = tf.reduce_sum(keras.losses.binary_crossentropy(x, reconst_x), axis=1)
        return tf.reduce_mean(reconst_loss)

    def train_step(self, data):
        with tf.GradientTape() as tape:
            mu_z, logvar_z, z = self.encoder(data)
            reconstructed_x = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstructed_x), axis=1
                )
            )
            kl_loss = -0.5 * (1 + logvar_z - tf.square(mu_z) - tf.exp(logvar_z))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss.update_state(total_loss)
        self.reconstruction_loss.update_state(reconstruction_loss)
        self.kl_loss.update_state(kl_loss)

        return {
            "loss": self.total_loss.result(),
            "reconstruction_loss": self.reconstruction_loss.result(),
            "kl_loss": self.kl_loss.result(),
        }

# %%
model = LSTM_VAE(TIME_STEPS, x_train.shape[2], 64, 32, 16, dtype="float32")
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001))
# Out:
# 2023-02-23 02:28:41.370664: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-02-23 02:28:41.418742: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-23 02:28:41.418788: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-23 02:28:41.422134: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-23 02:28:41.422238: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-23 02:28:41.423276: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-02-23 02:28:41.423617: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-02-23 02:28:41.424507: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-02-23 02:28:41.425284: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-02-23 02:28:41.425478: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-23 02:28:41.426201: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-02-23 02:28:41.426836: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-23 02:28:41.430725: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-23 02:28:41.432996: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-02-23 02:28:41.433074: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-23 02:28:41.986058: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-02-23 02:28:41.986090: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-02-23 02:28:41.986096: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-02-23 02:28:41.986940: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-02-23 02:28:41.986968: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 20843 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1f:00.0, compute capability: 8.6)

# %% [markdown]
# ## Train the model

# %%
history = model.fit(x_train,
                    epochs=50,
                    batch_size=128,
                    shuffle=False,
                    callbacks=[keras.callbacks.EarlyStopping(monitor="loss", patience=5, mode="min")],)
plt.plot(history.history["loss"], label="Training Loss")
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 273/273 [==============================] - 7s 27ms/step - loss: -22.2485 - reconstruction_loss: 12.8897 - kl_loss: 3.0013
# Epoch 2/50
# 273/273 [==============================] - 7s 26ms/step - loss: -22.7972 - reconstruction_loss: 12.7051 - kl_loss: 2.9813
# Epoch 3/50
# 273/273 [==============================] - 7s 26ms/step - loss: -22.9051 - reconstruction_loss: 12.5464 - kl_loss: 2.9401
# Epoch 4/50
# 273/273 [==============================] - 7s 27ms/step - loss: -22.6786 - reconstruction_loss: 12.8468 - kl_loss: 2.8539
# Epoch 5/50
# 273/273 [==============================] - 7s 26ms/step - loss: -23.9374 - reconstruction_loss: 12.5202 - kl_loss: 2.7892
# Epoch 6/50
# 273/273 [==============================] - 7s 26ms/step - loss: -24.0871 - reconstruction_loss: 12.1005 - kl_loss: 2.7666
# Epoch 7/50
# 273/273 [==============================] - 7s 27ms/step - loss: -25.2542 - reconstruction_loss: 11.4282 - kl_loss: 2.4560
# Epoch 8/50
# 273/273 [==============================] - 7s 26ms/step - loss: -27.2616 - reconstruction_loss: 9.6784 - kl_loss: 1.6151
# Epoch 9/50
# 273/273 [==============================] - 7s 27ms/step - loss: -32.8382 - reconstruction_loss: 4.4958 - kl_loss: 1.1504
# Epoch 10/50
# 273/273 [==============================] - 8s 28ms/step - loss: -35.1900 - reconstruction_loss: 3.8296 - kl_loss: 0.7338
# Epoch 11/50
# 273/273 [==============================] - 7s 27ms/step - loss: -37.2441 - reconstruction_loss: 1.9465 - kl_loss: 0.6911
# Epoch 12/50
# 273/273 [==============================] - 7s 27ms/step - loss: -36.9780 - reconstruction_loss: 2.0322 - kl_loss: 0.5775
# Epoch 13/50
# 273/273 [==============================] - 7s 25ms/step - loss: -36.5913 - reconstruction_loss: 3.6260 - kl_loss: 0.2991
# Epoch 14/50
# 273/273 [==============================] - 7s 27ms/step - loss: -30.4144 - reconstruction_loss: 9.4005 - kl_loss: 0.7803
# Epoch 15/50
# 273/273 [==============================] - 7s 27ms/step - loss: -31.1188 - reconstruction_loss: 6.1857 - kl_loss: 0.8693
# Epoch 16/50
# 273/273 [==============================] - 7s 26ms/step - loss: -35.6788 - reconstruction_loss: 3.3994 - kl_loss: 1.0299
# Epoch 17/50
# 273/273 [==============================] - 7s 26ms/step - loss: -34.7105 - reconstruction_loss: 3.1374 - kl_loss: 1.1405

# %% [markdown]
# ## Detecting anomalies
# ### We could set threshold my using train loss, and detect which points are anomalies

# %%
# Get prediction of train data
x_train_pred = model.decoder.predict(model.encoder.predict(x_train)[-1])
print("Predict train data done")

# Get test MAE loss.
x_test_pred = model.decoder.predict(model.encoder.predict(x_test)[-1])
print("Predict test data done")
# Out:
# Predict train data done
# Predict test data done

# %%
thresholds = {
    "abs_mean": compute_threshold(x_train, x_train_pred, option="abs_mean"),
    "abs_median": compute_threshold(x_train, x_train_pred, option="abs_median"),
    "abs_max": compute_threshold(x_train, x_train_pred, option="abs_max"),
    "square_mean": compute_threshold(x_train, x_train_pred, option="square_mean"),
    "square_median": compute_threshold(x_train, x_train_pred, option="square_median"),
    "rank": compute_threshold(x_train, x_train_pred, option="rank", label=df_test_label["label"]),
}
print(f'abs mean threshold: {thresholds["abs_mean"]:.3f}')
print(f'abs median threshold: {thresholds["abs_median"]:.3f}')
print(f'abs max threshold: {thresholds["abs_max"]:.3f}')
print(f'square mean threshold: {thresholds["square_mean"]:.3f}')
print(f'square median threshold: {thresholds["square_median"]:.3f}')
print(f'rank threshold: {thresholds["rank"]:.3f}')

# Detect all the samples which are anomalies.
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
# Out:
# abs mean threshold: 0.986
# abs median threshold: 0.976
# abs max threshold: 2.780
# square mean threshold: 1.479
# square median threshold: 1.416
# rank threshold: 1.725

# %%
# Choose the lowest loss of the anomaly datas((# of anomalies)th) as threshold by using rank option
threshold = thresholds["rank"]
print(f"threshold: {threshold:.3f}")

fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)

labels = df_test_label["label"].values.tolist()
dates = df_test.index


pd.DataFrame(np.sum(test_mae_loss, axis=1)).plot(ax=ax)
pd.DataFrame([threshold] * len(df_test)).plot(ax=ax)
ax.legend(["reconstruction error", "threshold"], loc="upper right")


temp_start = dates[0]
temp_date = dates[0]
temp_label = labels[0]

for xc, value in zip(dates, labels):
    if temp_label != value:
        if temp_label == True:
            ax.axvspan(temp_start, temp_date, alpha=0.2, color="orange")
        temp_start = xc
        temp_label = value
    temp_date = xc
if temp_label == True:
    ax.axvspan(temp_start, xc, alpha=0.2, color="orange")
# Out:
# threshold: 1.725

# %% [markdown]
# ## Predict & Evaluation

# %% [markdown]
# ## #1 if any included time step has anomalies => abnormal

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalies = np.sum(test_mae_loss, axis=1) > thresholds["rank"]
print("Number of anomaly samples: ", np.sum(anomalies))

anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.all(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)
print("Number of anomalous samples: ", len(anomalous_data_indices))

test_pred = np.zeros(len(df_test))
test_label = df_test_label["label"]
test_pred[anomalous_data_indices] = 1

accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  794
# Number of anomalous samples:  28
# accuracy: 98.55%
# precision: 0.00%
# recall: 0.00%
# f1: 0.00%

# %% [markdown]
# ## #2 If half of included time steps has anomaly => abnormal

# %%
# data i is an anomaly if ratio of anomalies sequences/involved total sequences >= 0.5
anomalies = np.sum(test_mae_loss, axis=1) > thresholds["rank"]
test_anomalies = np.zeros(len(df_test))
test_seqs = np.zeros(len(df_test))
test_label = df_test_label["label"]
print("Number of anomaly samples: ", np.sum(anomalies))

for idx, anomaly in enumerate(anomalies):
    test_seqs[idx : min(idx + TIME_STEPS, len(df_test))] += 1
    if anomaly:
        test_anomalies[idx : min(idx + TIME_STEPS, len(df_test))] += 1
test_pred_ratio = np.divide(test_anomalies, test_seqs)
test_pred = test_pred_ratio >= 0.5
print("Number of anomalous samples: ", sum(test_pred))


accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  794
# Number of anomalous samples:  719
# accuracy: 97.74%
# precision: 22.81%
# recall: 26.41%
# f1: 24.48%

# %%
idx = 4690
evaluation_array = [(test_seqs - test_anomalies)[idx:idx+400],
                    test_anomalies[idx:idx+400],
                    test_seqs[idx:idx+400],
                    test_pred_ratio[idx:idx+400],
                    test_pred[idx:idx+400],
                    df_test_label["label"][idx:idx+400]]

df = pd.DataFrame(evaluation_array, dtype=float)
df.index = ['Normal', 'Anomaly', '#Seq', 'Pred(%)', 'Pred', 'GT']
df.style.background_gradient(cmap='summer', axis=1)
# Out:
# <style type="text/css">
# #T_e6888_row0_col0, #T_e6888_row0_col1, #T_e6888_row0_col2, #T_e6888_row0_col3, #T_e6888_row0_col4, #T_e6888_row0_col5, #T_e6888_row0_col6, #T_e6888_row0_col7, #T_e6888_row0_col8, #T_e6888_row0_col9, #T_e6888_row0_col10, #T_e6888_row0_col11, #T_e6888_row0_col12, #T_e6888_row0_col13, #T_e6888_row0_col14, #T_e6888_row0_col15, #T_e6888_row0_col16, #T_e6888_row0_col17, #T_e6888_row0_col18, #T_e6888_row0_col19, #T_e6888_row0_col20, #T_e6888_row0_col21, #T_e6888_row0_col22, #T_e6888_row0_col23, #T_e6888_row0_col24, #T_e6888_row0_col25, #T_e6888_row0_col26, #T_e6888_row0_col27, #T_e6888_row0_col28, #T_e6888_row0_col29, #T_e6888_row0_col30, #T_e6888_row0_col31, #T_e6888_row0_col32, #T_e6888_row0_col33, #T_e6888_row0_col34, #T_e6888_row0_col35, #T_e6888_row0_col36, #T_e6888_row0_col37, #T_e6888_row0_col38, #T_e6888_row0_col39, #T_e6888_row0_col40, #T_e6888_row0_col41, #T_e6888_row0_col42, #T_e6888_row0_col43, #T_e6888_row0_col44, #T_e6888_row0_col45, #T_e6888_row0_col46, #T_e6888_row0_col47, #T_e6888_row0_col48, #T_e6888_row0_col49, #T_e6888_row0_col50, #T_e6888_row0_col51, #T_e6888_row0_col52, #T_e6888_row0_col53, #T_e6888_row0_col54, #T_e6888_row0_col55, #T_e6888_row0_col56, #T_e6888_row0_col57, #T_e6888_row0_col58, #T_e6888_row0_col59, #T_e6888_row0_col60, #T_e6888_row0_col61, #T_e6888_row0_col62, #T_e6888_row0_col63, #T_e6888_row0_col64, #T_e6888_row0_col65, #T_e6888_row0_col66, #T_e6888_row0_col67, #T_e6888_row0_col68, #T_e6888_row0_col69, #T_e6888_row0_col70, #T_e6888_row0_col71, #T_e6888_row0_col72, #T_e6888_row0_col73, #T_e6888_row0_col74, #T_e6888_row0_col75, #T_e6888_row0_col76, #T_e6888_row0_col77, #T_e6888_row0_col78, #T_e6888_row0_col79, #T_e6888_row0_col80, #T_e6888_row0_col81, #T_e6888_row0_col82, #T_e6888_row0_col83, #T_e6888_row0_col84, #T_e6888_row0_col85, #T_e6888_row0_col86, #T_e6888_row0_col87, #T_e6888_row0_col88, #T_e6888_row0_col89, #T_e6888_row0_col90, #T_e6888_row0_col91, #T_e6888_row0_col92, #T_e6888_row0_col93, #T_e6888_row0_col94, #T_e6888_row0_col95, #T_e6888_row0_col96, #T_e6888_row0_col97, #T_e6888_row0_col98, #T_e6888_row0_col99, #T_e6888_row0_col100, #T_e6888_row0_col101, #T_e6888_row0_col102, #T_e6888_row0_col103, #T_e6888_row0_col104, #T_e6888_row0_col105, #T_e6888_row0_col106, #T_e6888_row0_col107, #T_e6888_row0_col108, #T_e6888_row0_col109, #T_e6888_row0_col110, #T_e6888_row0_col111, #T_e6888_row0_col112, #T_e6888_row0_col113, #T_e6888_row0_col114, #T_e6888_row0_col115, #T_e6888_row0_col116, #T_e6888_row0_col117, #T_e6888_row0_col118, #T_e6888_row0_col119, #T_e6888_row0_col120, #T_e6888_row0_col121, #T_e6888_row0_col122, #T_e6888_row0_col123, #T_e6888_row0_col124, #T_e6888_row0_col125, #T_e6888_row0_col126, #T_e6888_row0_col127, #T_e6888_row0_col128, #T_e6888_row0_col129, #T_e6888_row0_col130, #T_e6888_row0_col131, #T_e6888_row0_col132, #T_e6888_row0_col133, #T_e6888_row0_col134, #T_e6888_row0_col135, #T_e6888_row0_col136, #T_e6888_row0_col137, #T_e6888_row0_col138, #T_e6888_row0_col139, #T_e6888_row0_col140, #T_e6888_row0_col141, #T_e6888_row0_col142, #T_e6888_row0_col143, #T_e6888_row0_col144, #T_e6888_row0_col145, #T_e6888_row0_col146, #T_e6888_row0_col147, #T_e6888_row0_col148, #T_e6888_row0_col149, #T_e6888_row0_col150, #T_e6888_row0_col151, #T_e6888_row0_col152, #T_e6888_row0_col153, #T_e6888_row0_col154, #T_e6888_row0_col155, #T_e6888_row0_col156, #T_e6888_row0_col157, #T_e6888_row0_col158, #T_e6888_row0_col159, #T_e6888_row0_col160, #T_e6888_row0_col161, #T_e6888_row0_col162, #T_e6888_row0_col163, #T_e6888_row0_col164, #T_e6888_row0_col165, #T_e6888_row0_col166, #T_e6888_row0_col167, #T_e6888_row0_col168, #T_e6888_row0_col169, #T_e6888_row0_col170, #T_e6888_row0_col171, #T_e6888_row0_col172, #T_e6888_row0_col173, #T_e6888_row0_col174, #T_e6888_row0_col175, #T_e6888_row0_col176, #T_e6888_row0_col177, #T_e6888_row0_col178, #T_e6888_row0_col179, #T_e6888_row0_col180, #T_e6888_row0_col181, #T_e6888_row0_col182, #T_e6888_row0_col183, #T_e6888_row0_col184, #T_e6888_row0_col185, #T_e6888_row0_col1 ...

# %% [markdown]
# ### #3 we could find the threshold with highest f1 score by calculating all cases

# %%
from evaluator import evaluate

label = create_sequences(df_test_label["label"], TIME_STEPS)
print(label.shape)
scores = evaluate(x_test, x_test_pred, label, n=10, scoring="abs_mean")
# Out:
# (44696, 100)

# %%
# print("f1:",np.max(scores['f1']))
idx = np.argmax(scores["f1"])

print(f"threshold: {scores['thresholds'][idx]}")
print(f"precision: {scores['precision'][idx]*100:.2f}%")
print(f"recall: {scores['recall'][idx]*100:.2f}%")
print(f"f1: {scores['f1'][idx]*100:.2f}%")
# Out:
# threshold: 4.601676177978516
# precision: 4.08%
# recall: 20.42%
# f1: 6.80%
