# %% [markdown]
# ## Introduction
#
# This script demonstrates how you can use a RNN-based model to detect anomalies in timeseries data.

# %% [markdown]
# ## Setup

# %%
import os
import random

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler


from evaluator import evaluate, compute_threshold
from dataloader import loader


# from sklearn.metrics import confusion_matrix

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# 2023-02-22 03:02:42.345602: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# # Load the data

# %%
df_train, df_test, df_test_label = loader(dataset="SMD")

# %% [markdown]
# ## Prepare training data

# %%
# Skip data normalization because SMAP datas were already normalized.
df_train = df_train.fillna(method="ffill")
scaler = StandardScaler()
scaler.fit(df_train)
df_training_value = pd.DataFrame(scaler.transform(df_train))
df_test_value = pd.DataFrame(scaler.transform(df_test))
print("Number of training samples:", len(df_training_value))
print("Number of training samples:", len(df_test_value))
# Out:
# Number of training samples: 28479
# Number of training samples: 28479

# %% [markdown]
# ### Create sequences
# Create sequences combining `TIME_STEPS` contiguous data values from the
# training data.

# %%
TIME_STEPS = 100


# Generated training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)

# Create sequences from test values.
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)
# Out:
# Training input shape:  (28380, 100, 38)
# Test input shape:  (28380, 100, 38)

# %% [markdown]
# ## Build a model

# %%
model = keras.Sequential(
    [
        layers.InputLayer(input_shape=(x_train.shape[1], x_train.shape[2])),
        layers.LSTM(64, return_sequences=True),
        layers.LSTM(32),
        layers.RepeatVector(x_train.shape[1]),
        layers.LSTM(32, return_sequences=True),
        layers.LSTM(64),
        layers.Dense(x_train.shape[1] * x_train.shape[2]),
        layers.Reshape([x_train.shape[1], x_train.shape[2]]),
    ]
)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# 2023-02-22 03:02:44.080178: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-02-22 03:02:44.122896: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-22 03:02:44.122939: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-22 03:02:44.125926: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-22 03:02:44.125997: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-22 03:02:44.126828: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-02-22 03:02:44.127092: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-02-22 03:02:44.127826: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-02-22 03:02:44.128451: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-02-22 03:02:44.128604: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-22 03:02:44.129189: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-02-22 03:02:44.129552: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-22 03:02:44.133314: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-22 03:02:44.134386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-02-22 03:02:44.134462: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-22 03:02:44.633563: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-02-22 03:02:44.633597: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-02-22 03:02:44.633602: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-02-22 03:02:44.634422: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-02-22 03:02:44.634448: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 17175 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1f:00.0, compute capability: 8.6)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 64)           26368
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 100, 32)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100, 32)           8320
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                24832
# _________________________________________________________________
# dense (Dense)                (None, 3800)              247000
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 38)           0
# =================================================================
# Total params: 318,936
# Trainable params: 318,936
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
history = model.fit(
    x_train,
    x_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min")],
)
# Out:
# 2023-02-22 03:02:45.935299: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-02-22 03:02:45.955873: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2900000000 Hz
# Epoch 1/50
# 2023-02-22 03:02:48.937315: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-22 03:02:49.574650: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2023-02-22 03:02:49.780328: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-22 03:02:50.392049: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-22 03:02:50.392115: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 178/178 [==============================] - 11s 36ms/step - loss: 0.4003 - val_loss: 0.3228
# Epoch 2/50
# 178/178 [==============================] - 6s 31ms/step - loss: 0.2726 - val_loss: 0.2933
# Epoch 3/50
# 178/178 [==============================] - 6s 31ms/step - loss: 0.2371 - val_loss: 0.2811
# Epoch 4/50
# 178/178 [==============================] - 6s 32ms/step - loss: 0.2249 - val_loss: 0.2823
# Epoch 5/50
# 178/178 [==============================] - 5s 30ms/step - loss: 0.2174 - val_loss: 0.2740
# Epoch 6/50
# 178/178 [==============================] - 5s 31ms/step - loss: 0.2167 - val_loss: 0.2586
# Epoch 7/50
# 178/178 [==============================] - 5s 30ms/step - loss: 0.2073 - val_loss: 0.2701
# Epoch 8/50
# 178/178 [==============================] - 6s 31ms/step - loss: 0.2047 - val_loss: 0.2557
# Epoch 9/50
# 178/178 [==============================] - 5s 30ms/step - loss: 0.2012 - val_loss: 0.2715
# Epoch 10/50
# 178/178 [==============================] - 5s 31ms/step - loss: 0.2058 - val_loss: 0.2590
# Epoch 11/50
# 178/178 [==============================] - 5s 31ms/step - loss: 0.1973 - val_loss: 0.2585
# Epoch 12/50
# 178/178 [==============================] - 5s 30ms/step - loss: 0.1987 - val_loss: 0.2723
# Epoch 13/50
# 178/178 [==============================] - 5s 31ms/step - loss: 0.1937 - val_loss: 0.2527
# Epoch 14/50
# 178/178 [==============================] - 5s 29ms/step - loss: 0.1914 - val_loss: 0.2515
# Epoch 15/50
# 178/178 [==============================] - 6s 31ms/step - loss: 0.1887 - val_loss: 0.2533
# Epoch 16/50
# 178/178 [==============================] - 5s 30ms/step - loss: 0.1917 - val_loss: 0.2633
# Epoch 17/50
# 178/178 [==============================] - 5s 31ms/step - loss: 0.1867 - val_loss: 0.2584
# Epoch 18/50
# 178/178 [==============================] - 5s 30ms/step - loss: 0.1838 - val_loss: 0.2586
# Epoch 19/50
# 178/178 [==============================] - 5s 30ms/step - loss: 0.1824 - val_loss: 0.2590

# %% [markdown]
# Let's plot training and validation loss to see how the training went.

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Detecting anomalies
# ### We could set threshold my using train loss, and detect which points are anomalies

# %%
# Get prediction of train data
x_train_pred = model.predict(x_train)
print("Predict train data done")

# Get test MAE loss.
x_test_pred = model.predict(x_test)
print("Predict test data done")
# Out:
# Predict train data done
# Predict test data done

# %%
thresholds = {
    "abs_mean": compute_threshold(x_train, x_train_pred, option="abs_mean"),
    "abs_median": compute_threshold(x_train, x_train_pred, option="abs_median"),
    "abs_max": compute_threshold(x_train, x_train_pred, option="abs_max"),
    "square_mean": compute_threshold(x_train, x_train_pred, option="square_mean"),
    "square_median": compute_threshold(x_train, x_train_pred, option="square_median"),
    "rank": compute_threshold(x_train, x_train_pred, option="rank", label=df_test_label["label"]),
}
print(f'abs mean threshold: {thresholds["abs_mean"]:.3f}')
print(f'abs median threshold: {thresholds["abs_median"]:.3f}')
print(f'abs median threshold: {thresholds["abs_max"]:.3f}')
print(f'square mean threshold: {thresholds["square_mean"]:.3f}')
print(f'square median threshold: {thresholds["square_median"]:.3f}')
print(f'rank threshold: {thresholds["rank"]:.3f}')

# Detect all the samples which are anomalies.
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
# Out:
# abs mean threshold: 7.887
# abs median threshold: 7.207
# abs median threshold: 31.309
# square mean threshold: 7.486
# square median threshold: 4.713
# rank threshold: 10.926

# %%
# Choose the lowest loss of the anomaly datas((# of anomalies)th) as threshold by using rank option
threshold = thresholds["abs_max"]
print(f"threshold: {threshold:.3f}")

fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)

labels = df_test_label["label"].values.tolist()
dates = df_test.index


pd.DataFrame(np.sum(test_mae_loss, axis=1)).plot(ax=ax)
pd.DataFrame([threshold] * len(df_test)).plot(ax=ax)
ax.legend(["reconstruction error", "threshold"], loc="upper right")


temp_start = dates[0]
temp_date = dates[0]
temp_label = labels[0]

for xc, value in zip(dates, labels):
    if temp_label != value:
        if temp_label == True:
            ax.axvspan(temp_start, temp_date, alpha=0.2, color="orange")
        temp_start = xc
        temp_label = value
    temp_date = xc
if temp_label == True:
    ax.axvspan(temp_start, xc, alpha=0.2, color="orange")
# Out:
# threshold: 31.309

# %% [markdown]
# ## Predict & Evaluation

# %% [markdown]
# ## #1 if any included time step has anomalies => abnormal

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalies = np.sum(test_mae_loss, axis=1) > thresholds["abs_max"]
print("Number of anomaly samples: ", np.sum(anomalies))

anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.all(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)
print("Number of anomalous samples: ", len(anomalous_data_indices))

test_pred = np.zeros(len(df_test))
test_label = df_test_label["label"]
test_pred[anomalous_data_indices] = 1

accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  6803
# Number of anomalous samples:  4417
# accuracy: 91.67%
# precision: 53.63%
# recall: 87.94%
# f1: 66.63%

# %% [markdown]
# ## #2 If half of included time steps has anomaly => abnormal

# %%
# data i is an anomaly if ratio of anomalies sequences/involved total sequences >= 0.5
anomalies = np.sum(test_mae_loss, axis=1) > thresholds["abs_max"]
test_anomalies = np.zeros(len(df_test))
test_seqs = np.zeros(len(df_test))
test_label = df_test_label["label"]
print("Number of anomaly samples: ", np.sum(anomalies))

for idx, anomaly in enumerate(anomalies):
    test_seqs[idx : min(idx + TIME_STEPS, len(df_test))] += 1
    if anomaly:
        test_anomalies[idx : min(idx + TIME_STEPS, len(df_test))] += 1
test_pred_ratio = np.divide(test_anomalies, test_seqs)
test_pred = test_pred_ratio >= 0.5
print("Number of anomalous samples: ", sum(test_pred))


accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  6803
# Number of anomalous samples:  6636
# accuracy: 85.63%
# precision: 39.47%
# recall: 97.22%
# f1: 56.14%

# %%
idx = 4690
evaluation_array = [(test_seqs - test_anomalies)[idx:idx+400],
                    test_anomalies[idx:idx+400],
                    test_seqs[idx:idx+400],
                    test_pred_ratio[idx:idx+400],
                    test_pred[idx:idx+400],
                    df_test_label["label"][idx:idx+400]]

df = pd.DataFrame(evaluation_array, dtype=float)
df.index = ['Normal', 'Anomaly', '#Seq', 'Pred(%)', 'Pred', 'GT']
df.style.background_gradient(cmap='summer', axis=1)
# Out:
# <style type="text/css">
# #T_afd88_row0_col0, #T_afd88_row0_col1, #T_afd88_row0_col2, #T_afd88_row0_col3, #T_afd88_row0_col4, #T_afd88_row0_col5, #T_afd88_row0_col6, #T_afd88_row0_col7, #T_afd88_row0_col8, #T_afd88_row0_col9, #T_afd88_row0_col10, #T_afd88_row0_col11, #T_afd88_row0_col12, #T_afd88_row0_col13, #T_afd88_row0_col14, #T_afd88_row0_col15, #T_afd88_row0_col16, #T_afd88_row0_col17, #T_afd88_row0_col18, #T_afd88_row0_col19, #T_afd88_row0_col20, #T_afd88_row0_col21, #T_afd88_row0_col22, #T_afd88_row0_col23, #T_afd88_row0_col24, #T_afd88_row0_col25, #T_afd88_row0_col26, #T_afd88_row0_col27, #T_afd88_row0_col28, #T_afd88_row0_col29, #T_afd88_row0_col30, #T_afd88_row0_col31, #T_afd88_row0_col32, #T_afd88_row0_col33, #T_afd88_row0_col34, #T_afd88_row0_col35, #T_afd88_row0_col36, #T_afd88_row0_col37, #T_afd88_row0_col38, #T_afd88_row0_col39, #T_afd88_row0_col40, #T_afd88_row0_col41, #T_afd88_row0_col42, #T_afd88_row0_col43, #T_afd88_row0_col44, #T_afd88_row0_col45, #T_afd88_row0_col46, #T_afd88_row0_col47, #T_afd88_row0_col48, #T_afd88_row0_col49, #T_afd88_row0_col50, #T_afd88_row0_col51, #T_afd88_row0_col52, #T_afd88_row0_col53, #T_afd88_row0_col54, #T_afd88_row0_col55, #T_afd88_row0_col56, #T_afd88_row0_col57, #T_afd88_row0_col58, #T_afd88_row0_col59, #T_afd88_row0_col60, #T_afd88_row0_col61, #T_afd88_row0_col62, #T_afd88_row0_col63, #T_afd88_row0_col64, #T_afd88_row0_col65, #T_afd88_row0_col66, #T_afd88_row0_col67, #T_afd88_row0_col68, #T_afd88_row0_col69, #T_afd88_row0_col70, #T_afd88_row0_col71, #T_afd88_row0_col72, #T_afd88_row0_col73, #T_afd88_row0_col74, #T_afd88_row0_col75, #T_afd88_row0_col76, #T_afd88_row0_col77, #T_afd88_row0_col78, #T_afd88_row0_col79, #T_afd88_row0_col80, #T_afd88_row0_col81, #T_afd88_row0_col82, #T_afd88_row0_col83, #T_afd88_row0_col84, #T_afd88_row0_col85, #T_afd88_row0_col86, #T_afd88_row0_col87, #T_afd88_row0_col88, #T_afd88_row0_col89, #T_afd88_row0_col90, #T_afd88_row0_col91, #T_afd88_row0_col92, #T_afd88_row0_col93, #T_afd88_row0_col94, #T_afd88_row0_col95, #T_afd88_row0_col96, #T_afd88_row0_col97, #T_afd88_row0_col98, #T_afd88_row0_col99, #T_afd88_row0_col100, #T_afd88_row0_col101, #T_afd88_row0_col102, #T_afd88_row0_col103, #T_afd88_row0_col104, #T_afd88_row0_col105, #T_afd88_row0_col106, #T_afd88_row0_col107, #T_afd88_row0_col108, #T_afd88_row0_col109, #T_afd88_row0_col110, #T_afd88_row0_col111, #T_afd88_row0_col112, #T_afd88_row0_col113, #T_afd88_row0_col114, #T_afd88_row0_col115, #T_afd88_row0_col116, #T_afd88_row0_col117, #T_afd88_row0_col118, #T_afd88_row0_col119, #T_afd88_row0_col120, #T_afd88_row0_col121, #T_afd88_row0_col122, #T_afd88_row0_col123, #T_afd88_row0_col124, #T_afd88_row0_col125, #T_afd88_row0_col126, #T_afd88_row0_col127, #T_afd88_row0_col128, #T_afd88_row0_col129, #T_afd88_row0_col130, #T_afd88_row0_col131, #T_afd88_row0_col132, #T_afd88_row0_col133, #T_afd88_row0_col134, #T_afd88_row0_col135, #T_afd88_row0_col136, #T_afd88_row0_col137, #T_afd88_row0_col138, #T_afd88_row0_col139, #T_afd88_row0_col140, #T_afd88_row0_col141, #T_afd88_row0_col142, #T_afd88_row0_col143, #T_afd88_row0_col144, #T_afd88_row0_col145, #T_afd88_row0_col146, #T_afd88_row0_col147, #T_afd88_row0_col148, #T_afd88_row0_col149, #T_afd88_row0_col150, #T_afd88_row0_col151, #T_afd88_row0_col152, #T_afd88_row0_col153, #T_afd88_row0_col154, #T_afd88_row0_col155, #T_afd88_row0_col156, #T_afd88_row0_col157, #T_afd88_row0_col158, #T_afd88_row0_col159, #T_afd88_row0_col160, #T_afd88_row0_col161, #T_afd88_row0_col162, #T_afd88_row0_col163, #T_afd88_row0_col164, #T_afd88_row0_col165, #T_afd88_row0_col166, #T_afd88_row0_col167, #T_afd88_row0_col168, #T_afd88_row0_col169, #T_afd88_row0_col170, #T_afd88_row0_col171, #T_afd88_row0_col172, #T_afd88_row0_col173, #T_afd88_row0_col174, #T_afd88_row0_col175, #T_afd88_row0_col176, #T_afd88_row0_col177, #T_afd88_row0_col178, #T_afd88_row0_col179, #T_afd88_row0_col180, #T_afd88_row0_col181, #T_afd88_row0_col182, #T_afd88_row0_col183, #T_afd88_row0_col184, #T_afd88_row0_col185, #T_afd88_row0_col1 ...

# %% [markdown]
# ### #3 we could find the threshold with highest f1 score by calculating all cases

# %%
from evaluator import evaluate

label = create_sequences(df_test_label["label"], TIME_STEPS)
print(label.shape)
scores = evaluate(x_test, x_test_pred, label, n=10, scoring="abs_mean")
# Out:
# (28380, 100)

# %%
# print("f1:",np.max(scores['f1']))
idx = np.argmax(scores["f1"])

print(f"threshold: {scores['thresholds'][idx]}")
print(f"precision: {scores['precision'][idx]*100:.2f}%")
print(f"recall: {scores['recall'][idx]*100:.2f}%")
print(f"f1: {scores['f1'][idx]*100:.2f}%")
# Out:
# threshold: 0.0
# precision: 12.28%
# recall: 100.00%
# f1: 21.88%
