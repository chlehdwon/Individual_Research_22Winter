# %% [markdown]
# ## Introduction
#
# This script demonstrates how you can use a RNN-based model to detect anomalies in timeseries data.

# %% [markdown]
# ## Setup

# %%
import os

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler


from evaluator import evaluate, compute_threshold
from dataloader import loader


# from sklearn.metrics import confusion_matrix

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"
# Out:
# 2023-02-16 14:31:28.509060: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# # Load the data
#
# We will use the SMAP data sets for training and testing.
#
# You can find raw data in https://s3-us-west-2.amazonaws.com/telemanom/data.ziphttps://s3-us-west-2.amazonaws.com/telemanom/data.zip
#
# I used preprocessed datasets with 25 dimensions.
#
# You can find preprocessed data in https://drive.google.com/drive/folders/1gisthCoE-RrKJ0j3KPV7xiibhHWT9qRmhttps://drive.google.com/drive/folders/1gisthCoE-RrKJ0j3KPV7xiibhHWT9qRm

# %%
df_train, df_test, df_test_label = loader(dataset="UCR")

# %% [markdown]
# ## Prepare training data

# %%
# Skip data normalization because SMAP datas were already normalized.
df_train = df_train.fillna(method="ffill")
scaler = StandardScaler()
scaler.fit(df_train)
df_training_value = pd.DataFrame(scaler.transform(df_train))
df_test_value = pd.DataFrame(scaler.transform(df_test))
print("Number of training samples:", len(df_training_value))
print("Number of training samples:", len(df_test_value))
# Out:
# Number of training samples: 35000
# Number of training samples: 44795

# %% [markdown]
# ### Create sequences
# Create sequences combining `TIME_STEPS` contiguous data values from the
# training data.

# %%
TIME_STEPS = 288


# Generated training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)

# Create sequences from test values.
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)
# Out:
# Training input shape:  (34713, 288, 1)
# Test input shape:  (44508, 288, 1)

# %% [markdown]
# ## Build a model

# %%
model = keras.Sequential(
    [
        layers.InputLayer(input_shape=(x_train.shape[1], x_train.shape[2])),
        layers.GRU(64, return_sequences=True),
        layers.GRU(32),
        layers.RepeatVector(x_train.shape[1]),
        layers.GRU(32, return_sequences=True),
        layers.GRU(64),
        layers.Dense(x_train.shape[1] * x_train.shape[2]),
        layers.Reshape([x_train.shape[1], x_train.shape[2]]),
    ]
)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# 2023-02-16 14:31:29.731380: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-02-16 14:31:29.776669: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:31:29.776703: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-16 14:31:29.779465: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-16 14:31:29.779533: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-16 14:31:29.780376: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-02-16 14:31:29.780638: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-02-16 14:31:29.781357: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-02-16 14:31:29.781969: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-02-16 14:31:29.782118: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-16 14:31:29.782776: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-02-16 14:31:29.783097: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-16 14:31:29.785782: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-16 14:31:29.786378: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-02-16 14:31:29.786413: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-16 14:31:30.275521: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-02-16 14:31:30.275558: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-02-16 14:31:30.275565: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-02-16 14:31:30.276520: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-02-16 14:31:30.276551: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9516 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1f:00.0, compute capability: 8.6)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 288, 64)           12864
# _________________________________________________________________
# gru_1 (GRU)                  (None, 32)                9408
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 288, 32)           0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 288, 32)           6336
# _________________________________________________________________
# gru_3 (GRU)                  (None, 64)                18816
# _________________________________________________________________
# dense (Dense)                (None, 288)               18720
# _________________________________________________________________
# reshape (Reshape)            (None, 288, 1)            0
# =================================================================
# Total params: 66,144
# Trainable params: 66,144
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
history = model.fit(
    x_train,
    x_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min")],
)
# Out:
# Epoch 1/50
# 2023-02-16 14:31:30.821317: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-02-16 14:31:30.839730: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2900000000 Hz
# 2023-02-16 14:31:33.710979: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-16 14:31:34.425455: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2023-02-16 14:31:34.633299: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-16 14:31:35.181944: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-16 14:31:35.182005: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 217/217 [==============================] - 16s 53ms/step - loss: 0.6888 - val_loss: 0.9748
# Epoch 2/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.4207 - val_loss: 0.7773
# Epoch 3/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.3063 - val_loss: 0.7341
# Epoch 4/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.2555 - val_loss: 0.7183
# Epoch 5/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.2295 - val_loss: 0.6896
# Epoch 6/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.2144 - val_loss: 0.7141
# Epoch 7/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.1972 - val_loss: 0.7048
# Epoch 8/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.1869 - val_loss: 0.7013
# Epoch 9/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.1792 - val_loss: 0.6908
# Epoch 10/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.1706 - val_loss: 0.6348
# Epoch 11/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.2089 - val_loss: 0.6590
# Epoch 12/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.1623 - val_loss: 0.6243
# Epoch 13/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.1530 - val_loss: 0.6198
# Epoch 14/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.1496 - val_loss: 0.6245
# Epoch 15/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.1463 - val_loss: 0.6041
# Epoch 16/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.1425 - val_loss: 0.6113
# Epoch 17/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.1395 - val_loss: 0.5801
# Epoch 18/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.1342 - val_loss: 0.5752
# Epoch 19/50
# 217/217 [==============================] - 11s 51ms/step - loss: 0.1394 - val_loss: 0.5929
# Epoch 20/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.1508 - val_loss: 0.5936
# Epoch 21/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.1264 - val_loss: 0.5875
# Epoch 22/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.1239 - val_loss: 0.5653
# Epoch 23/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.1228 - val_loss: 0.5702
# Epoch 24/50
# 217/217 [==============================] - 11s 51ms/step - loss: 0.1217 - val_loss: 0.5466
# Epoch 25/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.1177 - val_loss: 0.5473
# Epoch 26/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.1183 - val_loss: 0.5333
# Epoch 27/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.1156 - val_loss: 0.5423
# Epoch 28/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.1113 - val_loss: 0.5323
# Epoch 29/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.1108 - val_loss: 0.5287
# Epoch 30/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.1081 - val_loss: 0.5351
# Epoch 31/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.1042 - val_loss: 0.5101
# Epoch 32/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.1045 - val_loss: 0.5114
# Epoch 33/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.1038 - val_loss: 0.5262
# Epoch 34/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.0996 - val_loss: 0.4911
# Epoch 35/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.0997 - val_loss: 0.4816
# Epoch 36/50
# 217/217 [==============================] - 11s 48ms/step - loss: 0.0987 - val_loss: 0.4716
# Epoch 37/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.0940 - val_loss: 0.4814
# Epoch 38/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.0934 - val_loss: 0.4753
# Epoch 39/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.0931 - val_loss: 0.4736
# Epoch 40/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.0918 - val_loss: 0.4705
# Epoch 41/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.0930 - val_loss: 0.4512
# Epoch 42/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.0894 - val_loss: 0.4759
# Epoch 43/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.0878 - val_loss: 0.4502
# Epoch 44/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.0868 - val_loss: 0.4517
# Epoch 45/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.0866 - val_loss: 0.4799
# Epoch 46/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.0837 - val_loss: 0.4794
# Epoch 47/50
# 217/217 [==============================] - 11s 50ms/step - loss: 0.0829 - val_loss: 0.4488
# Epoch 48/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.0831 - val_loss: 0.4540
# Epoch 49/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.0807 - val_loss: 0.4410
# Epoch 50/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0.0792 - val_loss: 0.4860

# %% [markdown]
# Let's plot training and validation loss to see how the training went.

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Detecting anomalies
# ### We could set threshold my using train loss, and detect which points are anomalies

# %%
# Get prediction of train data
x_train_pred = model.predict(x_train)
print("Predict train data done")

# Get test MAE loss.
x_test_pred = model.predict(x_test)
print("Predict test data done")
# Out:
# Predict train data done
# Predict test data done

# %%
thresholds = {
    "abs_mean": compute_threshold(x_train, x_train_pred, option="abs_mean"),
    "abs_median": compute_threshold(x_train, x_train_pred, option="abs_median"),
    "abs_max": compute_threshold(x_train, x_train_pred, option="abs_max"),
    "square_mean": compute_threshold(x_train, x_train_pred, option="square_mean"),
    "square_median": compute_threshold(x_train, x_train_pred, option="square_median"),
    "rank": compute_threshold(x_train, x_train_pred, option="rank", label=df_test_label["label"]),
}
print(f'abs mean threshold: {thresholds["abs_mean"]:.3f}')
print(f'abs median threshold: {thresholds["abs_median"]:.3f}')
print(f'abs median threshold: {thresholds["abs_max"]:.3f}')
print(f'square mean threshold: {thresholds["square_mean"]:.3f}')
print(f'square median threshold: {thresholds["square_median"]:.3f}')
print(f'rank threshold: {thresholds["rank"]:.3f}')

# Choose the lowest loss of the anomaly datas((# of anomalies)th) as threshold by using rank option
threshold = thresholds["abs_max"]
print(f"threshold: {threshold:.3f}")

# Detect all the samples which are anomalies.
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
# anomalies = np.sum(test_mae_loss, axis=1) > threshold
# Out:
# abs mean threshold: 0.224
# abs median threshold: 0.162
# abs median threshold: 0.635
# square mean threshold: 0.159
# square median threshold: 0.043
# rank threshold: 1.018
# threshold: 0.635

# %%
fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)

labels = df_test_label["label"].values.tolist()
dates = df_test.index


pd.DataFrame(np.sum(test_mae_loss, axis=1)).plot(ax=ax)
pd.DataFrame([threshold] * len(df_test)).plot(ax=ax)
ax.legend(["reconstruction error", "threshold"], loc="upper right")


temp_start = dates[0]
temp_date = dates[0]
temp_label = labels[0]

for xc, value in zip(dates, labels):
    if temp_label != value:
        if temp_label == True:
            ax.axvspan(temp_start, temp_date, alpha=0.2, color="orange")
        temp_start = xc
        temp_label = value
    temp_date = xc
if temp_label == True:
    ax.axvspan(temp_start, xc, alpha=0.2, color="orange")

# %% [markdown]
# ## Predict & Evaluation

# %% [markdown]
# ## #1 if any included time step has anomalies => abnormal

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalies = np.sum(test_mae_loss, axis=1) > thresholds["abs_max"]
print("Number of anomaly samples: ", np.sum(anomalies))

anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.all(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)
print("Number of anomalous samples: ", len(anomalous_data_indices))

test_pred = np.zeros(len(df_test))
test_label = df_test_label["label"]
test_pred[anomalous_data_indices] = 1

accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  1960
# Number of anomalous samples:  686
# accuracy: 98.18%
# precision: 35.86%
# recall: 39.61%
# f1: 37.64%

# %% [markdown]
# ## #2 If half of included time steps has anomaly => abnormal

# %%
# data i is an anomaly if ratio of anomalies sequences/involved total sequences >= 0.5
anomalies = np.sum(test_mae_loss, axis=1) > thresholds["abs_max"]
test_anomalies = np.zeros(len(df_test))
test_seqs = np.zeros(len(df_test))
test_label = df_test_label["label"]
print("Number of anomaly samples: ", np.sum(anomalies))

for idx, anomaly in enumerate(anomalies):
    test_seqs[idx : min(idx + TIME_STEPS, len(df_test))] += 1
    if anomaly:
        test_anomalies[idx : min(idx + TIME_STEPS, len(df_test))] += 1
test_pred_ratio = np.divide(test_anomalies, test_seqs)
test_pred = test_pred_ratio >= 0.5
print("Number of anomalous samples: ", sum(test_pred))


accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  1960
# Number of anomalous samples:  1903
# accuracy: 96.53%
# precision: 25.43%
# recall: 77.94%
# f1: 38.35%

# %%
idx = 4690
evaluation_array = [(test_seqs - test_anomalies)[idx:idx+400],
                    test_anomalies[idx:idx+400],
                    test_seqs[idx:idx+400],
                    test_pred_ratio[idx:idx+400],
                    test_pred[idx:idx+400],
                    df_test_label["label"][idx:idx+400]]

df = pd.DataFrame(evaluation_array, dtype=float)
f5_row0_col102, #T_2a3f5_row0_col103, #T_2a3f5_row0_col104, #T_2a3f5_row0_col105, #T_2a3f5_row0_col106, #T_2a3f5_row0_col107, #T_2a3f5_row0_col108, #T_2a3f5_row0_col109, #T_2a3f5_row0_col110, #T_2a3f5_row0_col111, #T_2a3f5_row0_col112, #T_2a3f5_row0_col113, #T_2a3f5_row0_col114, #T_2a3f5_row0_col115, #T_2a3f5_row0_col116, #T_2a3f5_row0_col117, #T_2a3f5_row0_col118, #T_2a3f5_row0_col119, #T_2a3f5_row0_col120, #T_2a3f5_row0_col121, #T_2a3f5_row0_col122, #T_2a3f5_row0_col123, #T_2a3f5_row0_col124, #T_2a3f5_row0_col125, #T_2a3f5_row0_col126, #T_2a3f5_row0_col127, #T_2a3f5_row0_col128, #T_2a3f5_row0_col129, #T_2a3f5_row0_col130, #T_2a3f5_row0_col131, #T_2a3f5_row0_col132, #T_2a3f5_row0_col133, #T_2a3f5_row0_col134, #T_2a3f5_row0_col135, #T_2a3f5_row0_col136, #T_2a3f5_row0_col137, #T_2a3f5_row0_col138, #T_2a3f5_row0_col139, #T_2a3f5_row0_col140, #T_2a3f5_row0_col141, #T_2a3f5_row0_col142, #T_2a3f5_row0_col143, #T_2a3f5_row0_col144, #T_2a3f5_row0_col145, #T_2a3f5_row0_col146, #T_2a3f5_row0_col147, #T_2a3f5_row0_col148, #T_2a3f5_row0_col149, #T_2a3f5_row0_col150, #T_2a3f5_row0_col151, #T_2a3f5_row0_col152, #T_2a3f5_row0_col153, #T_2a3f5_row0_col154, #T_2a3f5_row0_col155, #T_2a3f5_row0_col156, #T_2a3f5_row0_col157, #T_2a3f5_row0_col158, #T_2a3f5_row0_col159, #T_2a3f5_row0_col160, #T_2a3f5_row0_col161, #T_2a3f5_row0_col162, #T_2a3f5_row0_col163, #T_2a3f5_row0_col164, #T_2a3f5_row0_col165, #T_2a3f5_row0_col166, #T_2a3f5_row0_col167, #T_2a3f5_row0_col168, #T_2a3f5_row0_col169, #T_2a3f5_row0_col170, #T_2a3f5_row0_col171, #T_2a3f5_row0_col172, #T_2a3f5_row0_col173, #T_2a3f5_row0_col174, #T_2a3f5_row0_col175, #T_2a3f5_row0_col176, #T_2a3f5_row0_col177, #T_2a3f5_row0_col178, #T_2a3f5_row0_col179, #T_2a3f5_row0_col180, #T_2a3f5_row0_col181, #T_2a3f5_row0_col182, #T_2a3f5_row0_col183, #T_2a3f5_row0_col184, #T_2a3f5_row0_col185, #T_2a3f5_row0_col1 ...

# %% [markdown]
# ### #3 we could find the threshold with highest f1 score by calculating all cases

# %%
from evaluator import evaluate

label = create_sequences(df_test_label["label"], TIME_STEPS)
print(label.shape)
scores = evaluate(x_test, x_test_pred, label, n=10, scoring="abs_mean")
# Out:
# (44508, 288)

# %%
# print("f1:",np.max(scores['f1']))
idx = np.argmax(scores["f1"])

print(f"threshold: {scores['thresholds'][idx]}")
print(f"precision: {scores['precision'][idx]*100:.2f}%")
print(f"recall: {scores['recall'][idx]*100:.2f}%")
print(f"f1: {scores['f1'][idx]*100:.2f}%")
# Out:
# threshold: 1.6013166427612304
# precision: 6.80%
# recall: 65.31%
# f1: 12.31%
