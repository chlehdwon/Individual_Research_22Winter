# %% [markdown]
# ## Introduction
#
# This script demonstrates how you can use a RNN-based model to detect anomalies in timeseries data.

# %% [markdown]
# ## Setup

# %%
import os
import random

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler

from evaluator import evaluate, compute_threshold
from dataloader import loader

# from sklearn.metrics import confusion_matrix

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# 2023-02-22 02:52:34.363265: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# # Load the data

# %%
df_train, df_test, df_test_label = loader(dataset="UCR")

# %% [markdown]
# ## Prepare training data

# %%
# Skip data normalization because SMAP datas were already normalized.
df_train = df_train.fillna(method="ffill")
scaler = StandardScaler()
scaler.fit(df_train)
df_training_value = pd.DataFrame(scaler.transform(df_train))
df_test_value = pd.DataFrame(scaler.transform(df_test))
print("Number of training samples:", len(df_training_value))
print("Number of training samples:", len(df_test_value))
# Out:
# Number of training samples: 35000
# Number of training samples: 44795

# %% [markdown]
# ### Create sequences
# Create sequences combining `TIME_STEPS` contiguous data values from the
# training data.

# %%
TIME_STEPS = 288


# Generated training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)

# Create sequences from test values.
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)
# Out:
# Training input shape:  (34713, 288, 1)
# Test input shape:  (44508, 288, 1)

# %% [markdown]
# ## Build a model

# %%
model = keras.Sequential(
    [
        layers.InputLayer(input_shape=(x_train.shape[1], x_train.shape[2])),
        layers.GRU(64, return_sequences=True),
        layers.GRU(32),
        layers.RepeatVector(x_train.shape[1]),
        layers.GRU(32, return_sequences=True),
        layers.GRU(64),
        layers.Dense(x_train.shape[1] * x_train.shape[2]),
        layers.Reshape([x_train.shape[1], x_train.shape[2]]),
    ]
)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# 2023-02-22 02:52:35.650375: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-02-22 02:52:35.695766: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-22 02:52:35.695806: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-22 02:52:35.699412: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-22 02:52:35.699491: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-22 02:52:35.700428: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-02-22 02:52:35.700673: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-02-22 02:52:35.701352: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-02-22 02:52:35.701960: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-02-22 02:52:35.702108: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-22 02:52:35.702688: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-02-22 02:52:35.703006: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-22 02:52:35.705817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-02-22 02:52:35.706332: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-02-22 02:52:35.706369: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-02-22 02:52:36.217291: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-02-22 02:52:36.217324: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-02-22 02:52:36.217330: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-02-22 02:52:36.218145: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-02-22 02:52:36.218172: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 21901 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1f:00.0, compute capability: 8.6)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 288, 64)           12864
# _________________________________________________________________
# gru_1 (GRU)                  (None, 32)                9408
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 288, 32)           0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 288, 32)           6336
# _________________________________________________________________
# gru_3 (GRU)                  (None, 64)                18816
# _________________________________________________________________
# dense (Dense)                (None, 288)               18720
# _________________________________________________________________
# reshape (Reshape)            (None, 288, 1)            0
# =================================================================
# Total params: 66,144
# Trainable params: 66,144
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
history = model.fit(
    x_train,
    x_train,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min")],
)
# Out:
# Epoch 1/50
# 2023-02-22 02:52:36.760393: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-02-22 02:52:36.779911: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2900000000 Hz
# 2023-02-22 02:52:39.868469: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-02-22 02:52:40.556040: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2023-02-22 02:52:40.748984: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-02-22 02:52:41.392591: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-02-22 02:52:41.392662: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 217/217 [==============================] - 16s 51ms/step - loss: 0.6626 - val_loss: 0.8186
# Epoch 2/50
# 217/217 [==============================] - 10s 48ms/step - loss: 0.3872 - val_loss: 0.7859
# Epoch 3/50
# 217/217 [==============================] - 11s 48ms/step - loss: 0.3062 - val_loss: 0.6639
# Epoch 4/50
# 217/217 [==============================] - 10s 47ms/step - loss: 0.2654 - val_loss: 0.6426
# Epoch 5/50
# 217/217 [==============================] - 10s 47ms/step - loss: 0.2466 - val_loss: 0.6377
# Epoch 6/50
# 217/217 [==============================] - 11s 49ms/step - loss: 0
# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Detecting anomalies
# ### We could set threshold my using train loss, and detect which points are anomalies

# %%
# Get prediction of train data
x_train_pred = model.predict(x_train)
print("Predict train data done")

# Get test MAE loss.
x_test_pred = model.predict(x_test)
print("Predict test data done")
# Out:
# Predict train data done
# Predict test data done

# %%
thresholds = {
    "abs_mean": compute_threshold(x_train, x_train_pred, option="abs_mean"),
    "abs_median": compute_threshold(x_train, x_train_pred, option="abs_median"),
    "abs_max": compute_threshold(x_train, x_train_pred, option="abs_max"),
    "square_mean": compute_threshold(x_train, x_train_pred, option="square_mean"),
    "square_median": compute_threshold(x_train, x_train_pred, option="square_median"),
    "rank": compute_threshold(x_train, x_train_pred, option="rank", label=df_test_label["label"]),
}
print(f'abs mean threshold: {thresholds["abs_mean"]:.3f}')
print(f'abs median threshold: {thresholds["abs_median"]:.3f}')
print(f'abs median threshold: {thresholds["abs_max"]:.3f}')
print(f'square mean threshold: {thresholds["square_mean"]:.3f}')
print(f'square median threshold: {thresholds["square_median"]:.3f}')
print(f'rank threshold: {thresholds["rank"]:.3f}')


# Detect all the samples which are anomalies.
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
# Out:
# abs mean threshold: 0.214
# abs median threshold: 0.165
# abs median threshold: 0.954
# square mean threshold: 0.145
# square median threshold: 0.051
# rank threshold: 0.783
# threshold: 0.954

# %%
# Choose the lowest loss of the anomaly datas((# of anomalies)th) as threshold by using rank option
threshold = thresholds["abs_max"]
print(f"threshold: {threshold:.3f}")

fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)

labels = df_test_label["label"].values.tolist()
dates = df_test.index


pd.DataFrame(np.sum(test_mae_loss, axis=1)).plot(ax=ax)
pd.DataFrame([threshold] * len(df_test)).plot(ax=ax)
ax.legend(["reconstruction error", "threshold"], loc="upper right")


temp_start = dates[0]
temp_date = dates[0]
temp_label = labels[0]

for xc, value in zip(dates, labels):
    if temp_label != value:
        if temp_label == True:
            ax.axvspan(temp_start, temp_date, alpha=0.2, color="orange")
        temp_start = xc
        temp_label = value
    temp_date = xc
if temp_label == True:
    ax.axvspan(temp_start, xc, alpha=0.2, color="orange")

# %% [markdown]
# ## Predict & Evaluation

# %% [markdown]
# ## #1 if any included time step has anomalies => abnormal

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalies = np.sum(test_mae_loss, axis=1) > thresholds["abs_max"]
print("Number of anomaly samples: ", np.sum(anomalies))

anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.all(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)
print("Number of anomalous samples: ", len(anomalous_data_indices))

test_pred = np.zeros(len(df_test))
test_label = df_test_label["label"]
test_pred[anomalous_data_indices] = 1

accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  1159
# Number of anomalous samples:  255
# accuracy: 98.59%
# precision: 47.84%
# recall: 19.65%
# f1: 27.85%

# %% [markdown]
# ## #2 If half of included time steps has anomaly => abnormal

# %%
# data i is an anomaly if ratio of anomalies sequences/involved total sequences >= 0.5
anomalies = np.sum(test_mae_loss, axis=1) > thresholds["abs_max"]
test_anomalies = np.zeros(len(df_test))
test_seqs = np.zeros(len(df_test))
test_label = df_test_label["label"]
print("Number of anomaly samples: ", np.sum(anomalies))

for idx, anomaly in enumerate(anomalies):
    test_seqs[idx : min(idx + TIME_STEPS, len(df_test))] += 1
    if anomaly:
        test_anomalies[idx : min(idx + TIME_STEPS, len(df_test))] += 1
test_pred_ratio = np.divide(test_anomalies, test_seqs)
test_pred = test_pred_ratio >= 0.5
print("Number of anomalous samples: ", sum(test_pred))


accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  1159
# Number of anomalous samples:  994
# accuracy: 98.38%
# precision: 44.77%
# recall: 71.66%
# f1: 55.11%

# %%
idx = 4690
evaluation_array = [(test_seqs - test_anomalies)[idx:idx+400],
                    test_anomalies[idx:idx+400],
                    test_seqs[idx:idx+400],
                    test_pred_ratio[idx:idx+400],
                    test_pred[idx:idx+400],
                    df_test_label["label"][idx:idx+400]]

df = pd.DataFrame(evaluation_array, dtype=float)
df.index = ['Normal', 'Anomaly', '#Seq', 'Pred(%)', 'Pred', 'GT']
df.style.background_gradient(cmap='summer', axis=1)
# Out:
# <style type="text/css">
# #T_5508e_row0_col0, #T_5508e_row0_col1, #T_5508e_row0_col2, #T_5508e_row0_col3, #T_5508e_row0_col4, #T_5508e_row0_col5, #T_5508e_row0_col6, #T_5508e_row0_col7, #T_5508e_row0_col8, #T_5508e_row0_col9, #T_5508e_row0_col10, #T_5508e_row0_col11, #T_5508e_row0_col12, #T_5508e_row0_col13, #T_5508e_row0_col14, #T_5508e_row0_col15, #T_5508e_row0_col16, #T_5508e_row0_col17, #T_5508e_row0_col18, #T_5508e_row0_col19, #T_5508e_row0_col20, #T_5508e_row0_col21, #T_5508e_row0_col22, #T_5508e_row0_col23, #T_5508e_row0_col24, #T_5508e_row0_col25, #T_5508e_row0_col26, #T_5508e_row0_col27, #T_5508e_row0_col28, #T_5508e_row0_col29, #T_5508e_row0_col30, #T_5508e_row0_col31, #T_5508e_row0_col32, #T_5508e_row0_col33, #T_5508e_row0_col34, #T_5508e_row0_col35, #T_5508e_row0_col36, #T_5508e_row0_col37, #T_5508e_row0_col38, #T_5508e_row0_col39, #T_5508e_row0_col40, #T_5508e_row0_col41, #T_5508e_row0_col42, #T_5508e_row0_col43, #T_5508e_row0_col44, #T_5508e_row0_col45, #T_5508e_row0_col46, #T_5508e_row0_col47, #T_5508e_row0_col48, #T_5508e_row0_col49, #T_5508e_row0_col50, #T_5508e_row0_col51, #T_5508e_row0_col52, #T_5508e_row0_col53, #T_5508e_row0_col54, #T_5508e_row0_col55, #T_5508e_row0_col56, #T_5508e_row0_col57, #T_5508e_row0_col58, #T_5508e_row0_col59, #T_5508e_row0_col60, #T_5508e_row0_col61, #T_5508e_row0_col62, #T_5508e_row0_col63, #T_5508e_row0_col64, #T_5508e_row0_col65, #T_5508e_row0_col66, #T_5508e_row0_col67, #T_5508e_row0_col68, #T_5508e_row0_col69, #T_5508e_row0_col70, #T_5508e_row0_col71, #T_5508e_row0_col72, #T_5508e_row0_col73, #T_5508e_row0_col74, #T_5508e_row0_col75, #T_5508e_row0_col76, #T_5508e_row0_col77, #T_5508e_row0_col78, #T_5508e_row0_col79, #T_5508e_row0_col80, #T_5508e_row0_col81, #T_5508e_row0_col82, #T_5508e_row0_col83, #T_5508e_row0_col84, #T_5508e_row0_col85, #T_5508e_row0_col86, #T_5508e_row0_col87, #T_5508e_row0_col88, #T_5508e_row0_col89, #T_5508e_row0_col90, #T_5508e_row0_col91, #T_5508e_row0_col92, #T_5508e_row0_col93, #T_5508e_row0_col94, #T_5508e_row0_col95, #T_5508e_row0_col96, #T_5508e_row0_col97, #T_5508e_row0_col98, #T_5508e_row0_col99, #T_5508e_row0_col100, #T_5508e_row0_col101, #T_5508e_row0_col102, #T_5508e_row0_col103, #T_5508e_row0_col104, #T_5508e_row0_col105, #T_5508e_row0_col106, #T_5508e_row0_col107, #T_5508e_row0_col108, #T_5508e_row0_col109, #T_5508e_row0_col110, #T_5508e_row0_col111, #T_5508e_row0_col112, #T_5508e_row0_col113, #T_5508e_row0_col114, #T_5508e_row0_col115, #T_5508e_row0_col116, #T_5508e_row0_col117, #T_5508e_row0_col118, #T_5508e_row0_col119, #T_5508e_row0_col120, #T_5508e_row0_col121, #T_5508e_row0_col122, #T_5508e_row0_col123, #T_5508e_row0_col124, #T_5508e_row0_col125, #T_5508e_row0_col126, #T_5508e_row0_col127, #T_5508e_row0_col128, #T_5508e_row0_col129, #T_5508e_row0_col130, #T_5508e_row0_col131, #T_5508e_row0_col132, #T_5508e_row0_col133, #T_5508e_row0_col134, #T_5508e_row0_col135, #T_5508e_row0_col136, #T_5508e_row0_col137, #T_5508e_row0_col138, #T_5508e_row0_col139, #T_5508e_row0_col140, #T_5508e_row0_col141, #T_5508e_row0_col142, #T_5508e_row0_col143, #T_5508e_row0_col144, #T_5508e_row0_col145, #T_5508e_row0_col146, #T_5508e_row0_col147, #T_5508e_row0_col148, #T_5508e_row0_col149, #T_5508e_row0_col150, #T_5508e_row0_col151, #T_5508e_row0_col152, #T_5508e_row0_col153, #T_5508e_row0_col154, #T_5508e_row0_col155, #T_5508e_row0_col156, #T_5508e_row0_col157, #T_5508e_row0_col158, #T_5508e_row0_col159, #T_5508e_row0_col160, #T_5508e_row0_col161, #T_5508e_row0_col162, #T_5508e_row0_col163, #T_5508e_row0_col164, #T_5508e_row0_col165, #T_5508e_row0_col166, #T_5508e_row0_col167, #T_5508e_row0_col168, #T_5508e_row0_col169, #T_5508e_row0_col170, #T_5508e_row0_col171, #T_5508e_row0_col172, #T_5508e_row0_col173, #T_5508e_row0_col174, #T_5508e_row0_col175, #T_5508e_row0_col176, #T_5508e_row0_col177, #T_5508e_row0_col178, #T_5508e_row0_col179, #T_5508e_row0_col180, #T_5508e_row0_col181, #T_5508e_row0_col182, #T_5508e_row0_col183, #T_5508e_row0_col184, #T_5508e_row0_col185, #T_5508e_row0_col1 ...

# %% [markdown]
# ### #3 we could find the threshold with highest f1 score by calculating all cases

# %%
from evaluator import evaluate

label = create_sequences(df_test_label["label"], TIME_STEPS)
print(label.shape)
scores = evaluate(x_test, x_test_pred, label, n=10, scoring="abs_mean")
# Out:
# (44508, 288)

# %%
# print("f1:",np.max(scores['f1']))
idx = np.argmax(scores["f1"])

print(f"threshold: {scores['thresholds'][idx]}")
print(f"precision: {scores['precision'][idx]*100:.2f}%")
print(f"recall: {scores['recall'][idx]*100:.2f}%")
print(f"f1: {scores['f1'][idx]*100:.2f}%")
# Out:
# threshold: 2.2101699829101564
# precision: 6.66%
# recall: 64.11%
# f1: 12.07%
