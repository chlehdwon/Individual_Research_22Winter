# %% [markdown]
# ## Introduction
#
# This script demonstrates how you can use a RNN-based model to detect anomalies in timeseries data.

# %% [markdown]
# ## Setup

# %%
import os
import random

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import backend as K
from sklearn.preprocessing import StandardScaler

from evaluator import evaluate, compute_threshold
from dataloader import loader


os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "1"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# 2023-03-22 20:54:04.413044: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# # Load the data

# %%
df_train, df_test, df_test_label = loader(dataset="SMAP")

# %% [markdown]
# ## Prepare training data

# %%
# Skip data normalization because SMAP datas were already normalized.
df_train = df_train.fillna(method="ffill")
scaler = StandardScaler()
scaler.fit(df_train)
df_training_value = pd.DataFrame(scaler.transform(df_train))
df_test_value = pd.DataFrame(scaler.transform(df_test))
print("Number of training samples:", len(df_training_value))
print("Number of training samples:", len(df_test_value))
# Out:
# Number of training samples: 135183
# Number of training samples: 427617

# %% [markdown]
# ### Create sequences
# Create sequences combining `TIME_STEPS` contiguous data values from the
# training data.

# %%
TIME_STEPS = 100


# Generated training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)

# Create sequences from test values.
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)
# Out:
# Training input shape:  (135084, 100, 25)
# Test input shape:  (427518, 100, 25)

# %% [markdown]
# ## Build a model

# %%
class Sampling(layers.Layer):
    def __init__(self, name="sampling"):
        super(Sampling, self).__init__(name=name)

    def call(self, inputs):
        mu, logvar = inputs
        batch, dim = tf.shape(mu)[0], tf.shape(mu)[1]
        sigma = K.exp(logvar * 0.5)
        epsilon = K.random_normal(shape=(batch, dim), mean=0.0, stddev=1.0)

        return mu + sigma * epsilon

# %%
class Encoder(keras.Model):
    def __init__(self, time_step, x_dim, h1_dim, h2_dim, z_dim, name="encoder", **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)
        self.encoder_inputs = keras.Input(shape=(time_step, x_dim))
        self.encoder_gru1 = layers.GRU(h1_dim, name="encoder_gru1", return_sequences="True")
        self.encoder_gru2 = layers.GRU(h2_dim, name="encoder_gru2")
        self.z_mean = layers.Dense(z_dim, name="z_mean")
        self.z_var = layers.Dense(z_dim, name="z_var")
        self.z_sample = Sampling()

    def call(self, inputs):
        self.encoder_inputs = inputs  # (None, time_steps, x_dim)
        hidden1 = self.encoder_gru1(self.encoder_inputs)  # (None, time_steps, h1_dim)
        hidden = self.encoder_gru2(hidden1)  # (None, h2_dim)
        mu_z = self.z_mean(hidden)  # (None, z_dim)
        logvar_z = self.z_var(hidden)  # (None, z_dim)
        z = self.z_sample((mu_z, logvar_z))  # (batch, z_dim)

        return mu_z, logvar_z, z

# %%
class Decoder(keras.Model):
    def __init__(self, time_step, x_dim, h1_dim, h2_dim, z_dim, name="decoder", **kwargs):
        super(Decoder, self).__init__(name=name, **kwargs)
        self.decoder_inputs = layers.RepeatVector(time_step, name="repeat_vector")
        self.decoder_gru1 = layers.GRU(h2_dim, name="decoder_gru1", return_sequences="True")
        self.decoder_gru2 = layers.GRU(h1_dim, name="decoder_gru2")
        self.dense = layers.Dense(x_dim * time_step, name="decoder_dense")
        self.reshape = layers.Reshape([time_step, x_dim], name="decoder_reshape")

    def call(self, inputs):
        z = self.decoder_inputs(inputs)  # (None, time_step, z_dim)
        hidden1 = self.decoder_gru1(z)  # (None, time_step, h2_dim)
        hidden = self.decoder_gru2(hidden1)  # (None, h1_dim)
        flatten = self.dense(hidden)  # (None, time_step * x_dim)
        reconstructed_x = self.reshape(flatten)  # (None, time_step, x_dim)

        return reconstructed_x

# %%
class GRY_VAE(keras.Model):
    def __init__(self, time_step, x_dim, h1_dim, h2_dim, z_dim, name="gru_vae", **kwargs):
        super(GRY_VAE, self).__init__(name=name, **kwargs)

        self.encoder = Encoder(time_step, x_dim, h1_dim, h2_dim, z_dim, **kwargs)
        self.decoder = Decoder(time_step, x_dim, h1_dim, h2_dim, z_dim, **kwargs)
        self.total_loss = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss = keras.metrics.Mean(name="kl_loss")

    def reconstruct_loss(self, x, reconst_x):
        reconst_loss = tf.reduce_sum(keras.losses.binary_crossentropy(x, reconst_x), axis=1)
        return tf.reduce_mean(reconst_loss)

    def train_step(self, data):
        with tf.GradientTape() as tape:
            mu_z, logvar_z, z = self.encoder(data)
            reconstructed_x = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstructed_x), axis=1
                )
            )
            kl_loss = -0.5 * (1 + logvar_z - tf.square(mu_z) - tf.exp(logvar_z))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss.update_state(total_loss)
        self.reconstruction_loss.update_state(reconstruction_loss)
        self.kl_loss.update_state(kl_loss)

        return {
            "loss": self.total_loss.result(),
            "reconstruction_loss": self.reconstruction_loss.result(),
            "kl_loss": self.kl_loss.result(),
        }

# %%
model = GRY_VAE(TIME_STEPS, x_train.shape[2], 64, 32, 16, dtype="float32")
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001))
# Out:
# 2023-03-22 20:54:08.096351: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-03-22 20:54:08.137810: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1e:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-22 20:54:08.138198: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-22 20:54:08.138547: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:20:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-22 20:54:08.138891: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:21:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-22 20:54:08.139233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 4 with properties:
# pciBusID: 0000:22:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-22 20:54:08.139572: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 5 with properties:
# pciBusID: 0000:23:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-22 20:54:08.139605: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-03-22 20:54:08.142478: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-03-22 20:54:08.142558: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-03-22 20:54:08.143459: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-03-22 20:54:08.143737: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-03-22 20:54:08.144516: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-03-22 20:54:08.145021: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-03-22 20:54:08.145153: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-03-22 20:54:08.148728: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3, 4, 5
# 2023-03-22 20:54:08.149113: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-22 20:54:08.829685: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1e:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-22 20:54:08.829984: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-22 20:54:08.830230: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:20:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-22 20:54:08.830474: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:21:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-22 20:54:08.830718: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 4 with properties:
# pciBusID: 0000:22:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-22 20:54:08.830958: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 5 with properties:
# pciBusID: 0000:23:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-22 20:54:08.833680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3, 4, 5
# 2023-03-22 20:54:08.833740: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-03-22 20:54:11.941697: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-22 20:54:11.941736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2 3 4 5
# 2023-03-22 20:54:11.941743: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N N N N N N
# 2023-03-22 20:54:11.941746: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   N N N N N N
# 2023-03-22 20:54:11.941749: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   N N N N N N
# 2023-03-22 20:54:11.941752: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 3:   N N N N N N
# 2023-03-22 20:54:11.941755: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 4:   N N N N N N
# 2023-03-22 20:54:11.941758: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 5:   N N N N N N
# 2023-03-22 20:54:11.945597: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-03-22 20:54:11.945641: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 21661 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1e:00.0, compute capability: 8.6)
# 2023-03-22 20:54:11.946543: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-03-22 20:54:11.946564: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 827 MB memory) -> physical GPU (device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1f:00.0, compute capability: 8.6)
# 2023-03-22 20:54:11.947104: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-03-22 20:54:11.947122: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 16883 MB memory) -> physical GPU (device: 2, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:20:00.0, compute capability: 8.6)
# 2023-03-22 20:54:11.947593: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-03-22 20:54:11.947609: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 16923 MB memory) -> physical GPU (device: 3, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:21:00.0, compute capability: 8.6)
# 2023-03-22 20:54:11.948113: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-03-22 20:54:11.948131: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:4 with 22312 MB memory) -> physical GPU (device: 4, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:22:00.0, compute capability: 8.6)
# 2023-03-22 20:54:11.948619: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-03-22 20:54:11.948634: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:5 with 20819 MB memory) -> physical GPU (device: 5, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:23:00.0, compute capability: 8.6)

# %% [markdown]
# ## Train the model

# %%
history = model.fit(x_train,
                    epochs=30,
                    batch_size=128,
                    shuffle=False)
plt.plot(history.history["loss"], label="Training Loss")
plt.legend()
plt.show()
# Out:
# 2023-03-22 20:54:13.530398: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-03-22 20:54:13.531980: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2900000000 Hz
# Epoch 1/30
# 2023-03-22 20:54:17.102306: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-03-22 20:54:17.747628: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2023-03-22 20:54:17.968879: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-03-22 20:54:18.532317: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-03-22 20:54:18.532388: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1056/1056 [==============================] - 30s 23ms/step - loss: -7.8695 - reconstruction_loss: -25.6099 - kl_loss: 3.5211
# Epoch 2/30
# 1056/1056 [==============================] - 25s 23ms/step - loss: -20.1735 - reconstruction_loss: -31.0085 - kl_loss: 3.8586
# Epoch 3/30
# 1056/1056 [==============================] - 25s 23ms/step - loss: -14.6661 - reconstruction_loss: -31.6692 - kl_loss: 4.0076
# Epoch 4/30
# 1056/1056 [==============================] - 25s 23ms/step - loss: -20.9037 - reconstruction_loss: -35.5240 - kl_loss: 4.6105
# Epoch 5/30
# 1056/1056 [==============================] - 25s 24ms/step - loss: -23.1285 - reconstruction_loss: -38.7480 - kl_loss: 3.9365
# Epoch 6/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -29.7036 - reconstruction_loss: -44.1870 - kl_loss: 5.2994
# Epoch 7/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -26.7976 - reconstruction_loss: -45.4471 - kl_loss: 4.9762
# Epoch 8/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -35.9653 - reconstruction_loss: -51.8318 - kl_loss: 6.0176
# Epoch 9/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -39.9549 - reconstruction_loss: -51.8697 - kl_loss: 6.8633
# Epoch 10/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -38.4232 - reconstruction_loss: -55.6864 - kl_loss: 6.9083
# Epoch 11/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -40.8101 - reconstruction_loss: -54.5823 - kl_loss: 6.1135
# Epoch 12/30
# 1056/1056 [==============================] - 25s 23ms/step - loss: -41.8762 - reconstruction_loss: -58.9684 - kl_loss: 7.1959
# Epoch 13/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -39.3342 - reconstruction_loss: -56.7488 - kl_loss: 6.7436
# Epoch 14/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -50.2118 - reconstruction_loss: -64.2070 - kl_loss: 6.2184
# Epoch 15/30
# 1056/1056 [==============================] - 25s 23ms/step - loss: -50.1961 - reconstruction_loss: -67.1952 - kl_loss: 6.3932
# Epoch 16/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -51.3729 - reconstruction_loss: -63.3030 - kl_loss: 6.5666
# Epoch 17/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -55.6725 - reconstruction_loss: -68.5332 - kl_loss: 6.7427
# Epoch 18/30
# 1056/1056 [==============================] - 23s 22ms/step - loss: -46.6656 - reconstruction_loss: -63.6995 - kl_loss: 6.5238
# Epoch 19/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -50.4433 - reconstruction_loss: -68.0333 - kl_loss: 7.2496
# Epoch 20/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -56.0114 - reconstruction_loss: -70.9620 - kl_loss: 6.7084
# Epoch 21/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -57.5228 - reconstruction_loss: -71.3368 - kl_loss: 6.6274
# Epoch 22/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -49.5892 - reconstruction_loss: -53.6007 - kl_loss: 6.4600
# Epoch 23/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -40.1132 - reconstruction_loss: -59.7831 - kl_loss: 6.8273
# Epoch 24/30
# 1056/1056 [==============================] - 25s 23ms/step - loss: -59.4555 - reconstruction_loss: -73.0761 - kl_loss: 6.3688
# Epoch 25/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -54.4488 - reconstruction_loss: -71.4011 - kl_loss: 6.7913
# Epoch 26/30
# 1056/1056 [==============================] - 24s 22ms/step - loss: -42.7911 - reconstruction_loss: -60.5418 - kl_loss: 8.6168
# Epoch 27/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -50.1735 - reconstruction_loss: -70.8932 - kl_loss: 7.5254
# Epoch 28/30
# 1056/1056 [==============================] - 23s 22ms/step - loss: -62.0112 - reconstruction_loss: -77.2264 - kl_loss: 7.1902
# Epoch 29/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -57.1522 - reconstruction_loss: -72.0263 - kl_loss: 6.8199
# Epoch 30/30
# 1056/1056 [==============================] - 24s 23ms/step - loss: -61.5317 - reconstruction_loss: -74.6296 - kl_loss: 7.0338

# %% [markdown]
# ## Detecting anomalies
# ### We could set threshold my using train loss, and detect which points are anomalies

# %%
# Get prediction of train data
x_train_pred = model.decoder.predict(model.encoder.predict(x_train)[-1])
print("Predict train data done")

# Get test MAE loss.
x_test_pred = model.decoder.predict(model.encoder.predict(x_test)[-1])
print("Predict test data done")
# Out:
# Predict train data done
# Predict test data done

# %%
thresholds = {
    "abs_mean": compute_threshold(x_train, x_train_pred, option="abs_mean"),
    "abs_median": compute_threshold(x_train, x_train_pred, option="abs_median"),
    "abs_max": compute_threshold(x_train, x_train_pred, option="abs_max"),
    "square_mean": compute_threshold(x_train, x_train_pred, option="square_mean"),
    "square_median": compute_threshold(x_train, x_train_pred, option="square_median"),
    "rank": compute_threshold(x_train, x_train_pred, option="rank", label=df_test_label["label"]),
}
print(f'abs mean threshold: {thresholds["abs_mean"]:.3f}')
print(f'abs median threshold: {thresholds["abs_median"]:.3f}')
print(f'abs max threshold: {thresholds["abs_max"]:.3f}')
print(f'square mean threshold: {thresholds["square_mean"]:.3f}')
print(f'square median threshold: {thresholds["square_median"]:.3f}')
print(f'rank threshold: {thresholds["rank"]:.3f}')

# Detect all the samples which are anomalies.
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
# Out:
# abs mean threshold: 17.344
# abs median threshold: 17.097
# abs max threshold: 72.526
# square mean threshold: 35.272
# square median threshold: 20.933
# rank threshold: 17.717

# %%
# Choose the lowest loss of the anomaly datas((# of anomalies)th) as threshold by using rank option
threshold = thresholds["rank"]
print(f"threshold: {threshold:.3f}")

fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)

labels = df_test_label["label"].values.tolist()
dates = df_test.index


pd.DataFrame(np.sum(test_mae_loss, axis=1)).plot(ax=ax)
pd.DataFrame([threshold] * len(df_test)).plot(ax=ax)
ax.legend(["reconstruction error", "threshold"], loc="upper right")


temp_start = dates[0]
temp_date = dates[0]
temp_label = labels[0]

for xc, value in zip(dates, labels):
    if temp_label != value:
        if temp_label == True:
            ax.axvspan(temp_start, temp_date, alpha=0.2, color="orange")
        temp_start = xc
        temp_label = value
    temp_date = xc
if temp_label == True:
    ax.axvspan(temp_start, xc, alpha=0.2, color="orange")
# Out:
# threshold: 17.717

# %% [markdown]
# ## Predict & Evaluation

# %% [markdown]
# ## #1 if any included time step has anomalies => abnormal

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalies = np.sum(test_mae_loss, axis=1) > threshold
print("Number of anomaly samples: ", np.sum(anomalies))

anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.any(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)
print("Number of anomalous samples: ", len(anomalous_data_indices))

test_pred = np.zeros(len(df_test))
test_label = df_test_label["label"]
test_pred[anomalous_data_indices] = 1

accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  170466
# Number of anomalous samples:  371679
# accuracy: 23.36%
# precision: 13.27%
# recall: 90.18%
# f1: 23.14%

# %% [markdown]
# ## #2 If half of included time steps has anomaly => abnormal

# %%
# data i is an anomaly if ratio of anomalies sequences/involved total sequences >= 0.5
anomalies = np.sum(test_mae_loss, axis=1) > threshold
test_anomalies = np.zeros(len(df_test))
test_seqs = np.zeros(len(df_test))
test_label = df_test_label["label"]
print("Number of anomaly samples: ", np.sum(anomalies))

for idx, anomaly in enumerate(anomalies):
    test_seqs[idx : min(idx + TIME_STEPS, len(df_test))] += 1
    if anomaly:
        test_anomalies[idx : min(idx + TIME_STEPS, len(df_test))] += 1
test_pred_ratio = np.divide(test_anomalies, test_seqs)
test_pred = test_pred_ratio >= 0.5
print("Number of anomalous samples: ", sum(test_pred))


accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  170466
# Number of anomalous samples:  202420
# accuracy: 52.75%
# precision: 13.60%
# recall: 50.34%
# f1: 21.42%

# %%
idx = 4690
evaluation_array = [(test_seqs - test_anomalies)[idx:idx+400],
                    test_anomalies[idx:idx+400],
                    test_seqs[idx:idx+400],
                    test_pred_ratio[idx:idx+400],
                    test_pred[idx:idx+400],
                    df_test_label["label"][idx:idx+400]]

df = pd.DataFrame(evaluation_array, dtype=float)
df.index = ['Normal', 'Anomaly', '#Seq', 'Pred(%)', 'Pred', 'GT']
df.style.background_gradient(cmap='summer', axis=1)
# Out:
# <style type="text/css">
# #T_cbf4c_row0_col0, #T_cbf4c_row0_col1, #T_cbf4c_row0_col2, #T_cbf4c_row1_col98, #T_cbf4c_row1_col99, #T_cbf4c_row1_col100, #T_cbf4c_row1_col101, #T_cbf4c_row2_col0, #T_cbf4c_row2_col1, #T_cbf4c_row2_col2, #T_cbf4c_row2_col3, #T_cbf4c_row2_col4, #T_cbf4c_row2_col5, #T_cbf4c_row2_col6, #T_cbf4c_row2_col7, #T_cbf4c_row2_col8, #T_cbf4c_row2_col9, #T_cbf4c_row2_col10, #T_cbf4c_row2_col11, #T_cbf4c_row2_col12, #T_cbf4c_row2_col13, #T_cbf4c_row2_col14, #T_cbf4c_row2_col15, #T_cbf4c_row2_col16, #T_cbf4c_row2_col17, #T_cbf4c_row2_col18, #T_cbf4c_row2_col19, #T_cbf4c_row2_col20, #T_cbf4c_row2_col21, #T_cbf4c_row2_col22, #T_cbf4c_row2_col23, #T_cbf4c_row2_col24, #T_cbf4c_row2_col25, #T_cbf4c_row2_col26, #T_cbf4c_row2_col27, #T_cbf4c_row2_col28, #T_cbf4c_row2_col29, #T_cbf4c_row2_col30, #T_cbf4c_row2_col31, #T_cbf4c_row2_col32, #T_cbf4c_row2_col33, #T_cbf4c_row2_col34, #T_cbf4c_row2_col35, #T_cbf4c_row2_col36, #T_cbf4c_row2_col37, #T_cbf4c_row2_col38, #T_cbf4c_row2_col39, #T_cbf4c_row2_col40, #T_cbf4c_row2_col41, #T_cbf4c_row2_col42, #T_cbf4c_row2_col43, #T_cbf4c_row2_col44, #T_cbf4c_row2_col45, #T_cbf4c_row2_col46, #T_cbf4c_row2_col47, #T_cbf4c_row2_col48, #T_cbf4c_row2_col49, #T_cbf4c_row2_col50, #T_cbf4c_row2_col51, #T_cbf4c_row2_col52, #T_cbf4c_row2_col53, #T_cbf4c_row2_col54, #T_cbf4c_row2_col55, #T_cbf4c_row2_col56, #T_cbf4c_row2_col57, #T_cbf4c_row2_col58, #T_cbf4c_row2_col59, #T_cbf4c_row2_col60, #T_cbf4c_row2_col61, #T_cbf4c_row2_col62, #T_cbf4c_row2_col63, #T_cbf4c_row2_col64, #T_cbf4c_row2_col65, #T_cbf4c_row2_col66, #T_cbf4c_row2_col67, #T_cbf4c_row2_col68, #T_cbf4c_row2_col69, #T_cbf4c_row2_col70, #T_cbf4c_row2_col71, #T_cbf4c_row2_col72, #T_cbf4c_row2_col73, #T_cbf4c_row2_col74, #T_cbf4c_row2_col75, #T_cbf4c_row2_col76, #T_cbf4c_row2_col77, #T_cbf4c_row2_col78, #T_cbf4c_row2_col79, #T_cbf4c_row2_col80, #T_cbf4c_row2_col81, #T_cbf4c_row2_col82, #T_cbf4c_row2_col83, #T_cbf4c_row2_col84, #T_cbf4c_row2_col85, #T_cbf4c_row2_col86, #T_cbf4c_row2_col87, #T_cbf4c_row2_col88, #T_cbf4c_row2_col89, #T_cbf4c_row2_col90, #T_cbf4c_row2_col91, #T_cbf4c_row2_col92, #T_cbf4c_row2_col93, #T_cbf4c_row2_col94, #T_cbf4c_row2_col95, #T_cbf4c_row2_col96, #T_cbf4c_row2_col97, #T_cbf4c_row2_col98, #T_cbf4c_row2_col99, #T_cbf4c_row2_col100, #T_cbf4c_row2_col101, #T_cbf4c_row2_col102, #T_cbf4c_row2_col103, #T_cbf4c_row2_col104, #T_cbf4c_row2_col105, #T_cbf4c_row2_col106, #T_cbf4c_row2_col107, #T_cbf4c_row2_col108, #T_cbf4c_row2_col109, #T_cbf4c_row2_col110, #T_cbf4c_row2_col111, #T_cbf4c_row2_col112, #T_cbf4c_row2_col113, #T_cbf4c_row2_col114, #T_cbf4c_row2_col115, #T_cbf4c_row2_col116, #T_cbf4c_row2_col117, #T_cbf4c_row2_col118, #T_cbf4c_row2_col119, #T_cbf4c_row2_col120, #T_cbf4c_row2_col121, #T_cbf4c_row2_col122, #T_cbf4c_row2_col123, #T_cbf4c_row2_col124, #T_cbf4c_row2_col125, #T_cbf4c_row2_col126, #T_cbf4c_row2_col127, #T_cbf4c_row2_col128, #T_cbf4c_row2_col129, #T_cbf4c_row2_col130, #T_cbf4c_row2_col131, #T_cbf4c_row2_col132, #T_cbf4c_row2_col133, #T_cbf4c_row2_col134, #T_cbf4c_row2_col135, #T_cbf4c_row2_col136, #T_cbf4c_row2_col137, #T_cbf4c_row2_col138, #T_cbf4c_row2_col139, #T_cbf4c_row2_col140, #T_cbf4c_row2_col141, #T_cbf4c_row2_col142, #T_cbf4c_row2_col143, #T_cbf4c_row2_col144, #T_cbf4c_row2_col145, #T_cbf4c_row2_col146, #T_cbf4c_row2_col147, #T_cbf4c_row2_col148, #T_cbf4c_row2_col149, #T_cbf4c_row2_col150, #T_cbf4c_row2_col151, #T_cbf4c_row2_col152, #T_cbf4c_row2_col153, #T_cbf4c_row2_col154, #T_cbf4c_row2_col155, #T_cbf4c_row2_col156, #T_cbf4c_row2_col157, #T_cbf4c_row2_col158, #T_cbf4c_row2_col159, #T_cbf4c_row2_col160, #T_cbf4c_row2_col161, #T_cbf4c_row2_col162, #T_cbf4c_row2_col163, #T_cbf4c_row2_col164, #T_cbf4c_row2_col165, #T_cbf4c_row2_col166, #T_cbf4c_row2_col167, #T_cbf4c_row2_col168, #T_cbf4c_row2_col169, #T_cbf4c_row2_col170, #T_cbf4c_row2_col171, #T_cbf4c_row2_col172, #T_cbf4c_row2_col173, #T_cbf4c_row2_col174, #T_cbf4c_row2_col175, #T_cbf4c_row2_col176, #T_cbf4c_row2_col177, #T_cbf4c_row2_col178, #T_cbf4c_row2_col179, #T_c ...

# %% [markdown]
# ### #3 we could find the threshold with highest f1 score by calculating all cases

# %%
from evaluator import evaluate

label = create_sequences(df_test_label["label"], TIME_STEPS)
print(label.shape)
scores = evaluate(x_test, x_test_pred, label, n=10, scoring="abs_mean")
# Out:
# (427518, 100)

# %%
# print("f1:",np.max(scores['f1']))
idx = np.argmax(scores["f1"])

print(f"threshold: {scores['thresholds'][idx]}")
print(f"precision: {scores['precision'][idx]*100:.2f}%")
print(f"recall: {scores['recall'][idx]*100:.2f}%")
print(f"f1: {scores['f1'][idx]*100:.2f}%")
# Out:
# threshold: 0.0
# precision: 14.35%
# recall: 100.00%
# f1: 25.09%
