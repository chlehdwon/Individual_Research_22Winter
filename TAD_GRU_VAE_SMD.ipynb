# %% [markdown]
# ## Introduction
#
# This script demonstrates how you can use a RNN-based model to detect anomalies in timeseries data.

# %% [markdown]
# ## Setup

# %%
import os
import random

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import backend as K
from sklearn.preprocessing import StandardScaler

from evaluator import evaluate, compute_threshold
from dataloader import loader


os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# 2023-03-23 17:45:13.970246: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# # Load the data

# %%
df_train, df_test, df_test_label = loader(dataset="SMD")

# %% [markdown]
# ## Prepare training data

# %%
# Skip data normalization because SMAP datas were already normalized.
df_train = df_train.fillna(method="ffill")
scaler = StandardScaler()
scaler.fit(df_train)
df_training_value = pd.DataFrame(scaler.transform(df_train))
df_test_value = pd.DataFrame(scaler.transform(df_test))
print("Number of training samples:", len(df_training_value))
print("Number of training samples:", len(df_test_value))
# Out:
# Number of training samples: 28479
# Number of training samples: 28479

# %% [markdown]
# ### Create sequences
# Create sequences combining `TIME_STEPS` contiguous data values from the
# training data.

# %%
TIME_STEPS = 100


# Generated training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)

# Create sequences from test values.
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)
# Out:
# Training input shape:  (28380, 100, 38)
# Test input shape:  (28380, 100, 38)

# %% [markdown]
# ## Build a model

# %%
class Sampling(layers.Layer):
    def __init__(self, name="sampling"):
        super(Sampling, self).__init__(name=name)

    def call(self, inputs):
        mu, logvar = inputs
        batch, dim = tf.shape(mu)[0], tf.shape(mu)[1]
        sigma = K.exp(logvar * 0.5)
        epsilon = K.random_normal(shape=(batch, dim), mean=0.0, stddev=1.0)

        return mu + sigma * epsilon

# %%
class Encoder(keras.Model):
    def __init__(self, time_step, x_dim, h1_dim, h2_dim, z_dim, name="encoder", **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)
        self.encoder_inputs = keras.Input(shape=(time_step, x_dim))
        self.encoder_gru1 = layers.GRU(h1_dim, name="encoder_gru1", return_sequences="True")
        self.encoder_gru2 = layers.GRU(h2_dim, name="encoder_gru2")
        self.z_mean = layers.Dense(z_dim, name="z_mean")
        self.z_var = layers.Dense(z_dim, name="z_var")
        self.z_sample = Sampling()

    def call(self, inputs):
        self.encoder_inputs = inputs  # (None, time_steps, x_dim)
        hidden1 = self.encoder_gru1(self.encoder_inputs)  # (None, time_steps, h1_dim)
        hidden = self.encoder_gru2(hidden1)  # (None, h2_dim)
        mu_z = self.z_mean(hidden)  # (None, z_dim)
        logvar_z = self.z_var(hidden)  # (None, z_dim)
        z = self.z_sample((mu_z, logvar_z))  # (batch, z_dim)

        return mu_z, logvar_z, z

# %%
class Decoder(keras.Model):
    def __init__(self, time_step, x_dim, h1_dim, h2_dim, z_dim, name="decoder", **kwargs):
        super(Decoder, self).__init__(name=name, **kwargs)
        self.decoder_inputs = layers.RepeatVector(time_step, name="repeat_vector")
        self.decoder_gru1 = layers.GRU(h2_dim, name="decoder_gru1", return_sequences="True")
        self.decoder_gru2 = layers.GRU(h1_dim, name="decoder_gru2")
        self.dense = layers.Dense(x_dim * time_step, name="decoder_dense")
        self.reshape = layers.Reshape([time_step, x_dim], name="decoder_reshape")

    def call(self, inputs):
        z = self.decoder_inputs(inputs)  # (None, time_step, z_dim)
        hidden1 = self.decoder_gru1(z)  # (None, time_step, h2_dim)
        hidden = self.decoder_gru2(hidden1)  # (None, h1_dim)
        flatten = self.dense(hidden)  # (None, time_step * x_dim)
        reconstructed_x = self.reshape(flatten)  # (None, time_step, x_dim)

        return reconstructed_x

# %%
class GRY_VAE(keras.Model):
    def __init__(self, time_step, x_dim, h1_dim, h2_dim, z_dim, name="gru_vae", **kwargs):
        super(GRY_VAE, self).__init__(name=name, **kwargs)

        self.encoder = Encoder(time_step, x_dim, h1_dim, h2_dim, z_dim, **kwargs)
        self.decoder = Decoder(time_step, x_dim, h1_dim, h2_dim, z_dim, **kwargs)
        self.total_loss = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss = keras.metrics.Mean(name="kl_loss")

    def reconstruct_loss(self, x, reconst_x):
        reconst_loss = tf.reduce_sum(keras.losses.binary_crossentropy(x, reconst_x), axis=1)
        return tf.reduce_mean(reconst_loss)

    def train_step(self, data):
        with tf.GradientTape() as tape:
            mu_z, logvar_z, z = self.encoder(data)
            reconstructed_x = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstructed_x), axis=1
                )
            )
            kl_loss = -0.5 * (1 + logvar_z - tf.square(mu_z) - tf.exp(logvar_z))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss.update_state(total_loss)
        self.reconstruction_loss.update_state(reconstruction_loss)
        self.kl_loss.update_state(kl_loss)

        return {
            "loss": self.total_loss.result(),
            "reconstruction_loss": self.reconstruction_loss.result(),
            "kl_loss": self.kl_loss.result(),
        }

# %%
model = GRY_VAE(TIME_STEPS, x_train.shape[2], 64, 32, 16, dtype="float32")
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001))
# Out:
# 2023-03-23 17:45:15.686115: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-03-23 17:45:15.732434: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-23 17:45:15.732481: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-03-23 17:45:15.735369: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-03-23 17:45:15.735466: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-03-23 17:45:15.736370: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-03-23 17:45:15.736655: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-03-23 17:45:15.737417: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-03-23 17:45:15.738102: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-03-23 17:45:15.738275: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-03-23 17:45:15.738900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-23 17:45:15.739506: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-23 17:45:15.743853: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-23 17:45:15.744924: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-23 17:45:15.745004: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-03-23 17:45:16.262113: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-23 17:45:16.262144: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-23 17:45:16.262151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-23 17:45:16.263173: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-03-23 17:45:16.263206: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3630 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1f:00.0, compute capability: 8.6)

# %% [markdown]
# ## Train the model

# %%
history = model.fit(x_train,
                    epochs=30,
                    batch_size=128,
                    shuffle=False)
plt.plot(history.history["loss"], label="Training Loss")
plt.legend()
plt.show()
# Out:
# 2023-03-23 17:45:16.852922: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-03-23 17:45:16.872418: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2900000000 Hz
# Epoch 1/30
# 2023-03-23 17:45:20.450318: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-03-23 17:45:21.149677: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2023-03-23 17:45:21.322279: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-03-23 17:45:21.939151: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-03-23 17:45:21.939224: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 222/222 [==============================] - 11s 25ms/step - loss: -357.4009 - reconstruction_loss: -277.4356 - kl_loss: 6.2075
# Epoch 2/30
# 222/222 [==============================] - 5s 25ms/step - loss: -393.1441 - reconstruction_loss: -308.2966 - kl_loss: 6.0138
# Epoch 3/30
# 222/222 [==============================] - 5s 24ms/step - loss: -429.0934 - reconstruction_loss: -354.7217 - kl_loss: 8.1975
# Epoch 4/30
# 222/222 [==============================] - 5s 24ms/step - loss: -427.3857 - reconstruction_loss: -358.8747 - kl_loss: 8.9400
# Epoch 5/30
# 222/222 [==============================] - 5s 23ms/step - loss: -442.8330 - reconstruction_loss: -372.5996 - kl_loss: 8.4517
# Epoch 6/30
# 222/222 [==============================] - 5s 23ms/step - loss: -450.5482 - reconstruction_loss: -379.5152 - kl_loss: 7.2866
# Epoch 7/30
# 222/222 [==============================] - 5s 24ms/step - loss: -447.3293 - reconstruction_loss: -377.5928 - kl_loss: 7.7116
# Epoch 8/30
# 222/222 [==============================] - 5s 22ms/step - loss: -455.5319 - reconstruction_loss: -386.8816 - kl_loss: 7.7433
# Epoch 9/30
# 222/222 [==============================] - 5s 23ms/step - loss: -461.9582 - reconstruction_loss: -393.7935 - kl_loss: 8.0220
# Epoch 10/30
# 222/222 [==============================] - 5s 23ms/step - loss: -462.2370 - reconstruction_loss: -394.4315 - kl_loss: 8.5262
# Epoch 11/30
# 222/222 [==============================] - 5s 23ms/step - loss: -460.4621 - reconstruction_loss: -395.1400 - kl_loss: 8.8967
# Epoch 12/30
# 222/222 [==============================] - 5s 24ms/step - loss: -469.7919 - reconstruction_loss: -399.5616 - kl_loss: 8.4726
# Epoch 13/30
# 222/222 [==============================] - 5s 23ms/step - loss: -469.3530 - reconstruction_loss: -400.0367 - kl_loss: 9.0869
# Epoch 14/30
# 222/222 [==============================] - 5s 22ms/step - loss: -469.2322 - reconstruction_loss: -401.7205 - kl_loss: 8.9830
# Epoch 15/30
# 222/222 [==============================] - 5s 23ms/step - loss: -469.5260 - reconstruction_loss: -399.3687 - kl_loss: 8.8908
# Epoch 16/30
# 222/222 [==============================] - 5s 23ms/step - loss: -475.0064 - reconstruction_loss: -405.8311 - kl_loss: 8.9057
# Epoch 17/30
# 222/222 [==============================] - 5s 23ms/step - loss: -472.4142 - reconstruction_loss: -393.3289 - kl_loss: 9.0126
# Epoch 18/30
# 222/222 [==============================] - 5s 23ms/step - loss: -473.8123 - reconstruction_loss: -405.1346 - kl_loss: 8.9329
# Epoch 19/30
# 222/222 [==============================] - 5s 23ms/step - loss: -476.4919 - reconstruction_loss: -407.5903 - kl_loss: 8.5287
# Epoch 20/30
# 222/222 [==============================] - 5s 23ms/step - loss: -479.8920 - reconstruction_loss: -408.8608 - kl_loss: 8.5822
# Epoch 21/30
# 222/222 [==============================] - 5s 23ms/step - loss: -477.5767 - reconstruction_loss: -407.1235 - kl_loss: 8.7898
# Epoch 22/30
# 222/222 [==============================] - 5s 22ms/step - loss: -480.6930 - reconstruction_loss: -410.5713 - kl_loss: 8.4417
# Epoch 23/30
# 222/222 [==============================] - 5s 22ms/step - loss: -480.0648 - reconstruction_loss: -411.4362 - kl_loss: 8.5022
# Epoch 24/30
# 222/222 [==============================] - 5s 23ms/step - loss: -479.2693 - reconstruction_loss: -410.8207 - kl_loss: 8.8800
# Epoch 25/30
# 222/222 [==============================] - 5s 23ms/step - loss: -479.5513 - reconstruction_loss: -412.2882 - kl_loss: 8.6026
# Epoch 26/30
# 222/222 [==============================] - 5s 22ms/step - loss: -483.3205 - reconstruction_loss: -414.1887 - kl_loss: 8.5360
# Epoch 27/30
# 222/222 [==============================] - 5s 22ms/step - loss: -481.1622 - reconstruction_loss: -412.6821 - kl_loss: 8.2989
# Epoch 28/30
# 222/222 [==============================] - 5s 23ms/step - loss: -483.0383 - reconstruction_loss: -413.4040 - kl_loss: 8.6308
# Epoch 29/30
# 222/222 [==============================] - 5s 22ms/step - loss: -477.3928 - reconstruction_loss: -413.1496 - kl_loss: 8.6014
# Epoch 30/30
# 222/222 [==============================] - 5s 23ms/step - loss: -485.5271 - reconstruction_loss: -414.7475 - kl_loss: 8.5108

# %% [markdown]
# ## Detecting anomalies
# ### We could set threshold my using train loss, and detect which points are anomalies

# %%
# Get prediction of train data
x_train_pred = model.decoder.predict(model.encoder.predict(x_train)[-1])
print("Predict train data done")

# Get test MAE loss.
x_test_pred = model.decoder.predict(model.encoder.predict(x_test)[-1])
print("Predict test data done")
# Out:
# Predict train data done
# Predict test data done

# %%
thresholds = {
    "abs_mean": compute_threshold(x_train, x_train_pred, option="abs_mean"),
    "abs_median": compute_threshold(x_train, x_train_pred, option="abs_median"),
    "abs_max": compute_threshold(x_train, x_train_pred, option="abs_max"),
    "square_mean": compute_threshold(x_train, x_train_pred, option="square_mean"),
    "square_median": compute_threshold(x_train, x_train_pred, option="square_median"),
    "rank": compute_threshold(x_train, x_train_pred, option="rank", label=df_test_label["label"]),
}
print(f'abs mean threshold: {thresholds["abs_mean"]:.3f}')
print(f'abs median threshold: {thresholds["abs_median"]:.3f}')
print(f'abs max threshold: {thresholds["abs_max"]:.3f}')
print(f'square mean threshold: {thresholds["square_mean"]:.3f}')
print(f'square median threshold: {thresholds["square_median"]:.3f}')
print(f'rank threshold: {thresholds["rank"]:.3f}')

# Detect all the samples which are anomalies.
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
# Out:
# abs mean threshold: 14.417
# abs median threshold: 12.578
# abs max threshold: 45.708
# square mean threshold: 15.032
# square median threshold: 8.317
# rank threshold: 18.531

# %%
# Choose the lowest loss of the anomaly datas((# of anomalies)th) as threshold by using rank option
threshold = thresholds["abs_max"]
print(f"threshold: {threshold:.3f}")

fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)

labels = df_test_label["label"].values.tolist()
dates = df_test.index


pd.DataFrame(np.sum(test_mae_loss, axis=1)).plot(ax=ax)
pd.DataFrame([threshold] * len(df_test)).plot(ax=ax)
ax.legend(["reconstruction error", "threshold"], loc="upper right")


temp_start = dates[0]
temp_date = dates[0]
temp_label = labels[0]

for xc, value in zip(dates, labels):
    if temp_label != value:
        if temp_label == True:
            ax.axvspan(temp_start, temp_date, alpha=0.2, color="orange")
        temp_start = xc
        temp_label = value
    temp_date = xc
if temp_label == True:
    ax.axvspan(temp_start, xc, alpha=0.2, color="orange")
# Out:
# threshold: 45.708

# %% [markdown]
# ## Predict & Evaluation

# %% [markdown]
# ## #1 if any included time step has anomalies => abnormal

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalies = np.sum(test_mae_loss, axis=1) > threshold
print("Number of anomaly samples: ", np.sum(anomalies))

anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.all(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)
print("Number of anomalous samples: ", len(anomalous_data_indices))

test_pred = np.zeros(len(df_test))
test_label = df_test_label["label"]
test_pred[anomalous_data_indices] = 1

accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  4724
# Number of anomalous samples:  2861
# accuracy: 91.39%
# precision: 54.25%
# recall: 57.61%
# f1: 55.88%

# %% [markdown]
# ## #2 If half of included time steps has anomaly => abnormal

# %%
# data i is an anomaly if ratio of anomalies sequences/involved total sequences >= 0.5
anomalies = np.sum(test_mae_loss, axis=1) > threshold
test_anomalies = np.zeros(len(df_test))
test_seqs = np.zeros(len(df_test))
test_label = df_test_label["label"]
print("Number of anomaly samples: ", np.sum(anomalies))

for idx, anomaly in enumerate(anomalies):
    test_seqs[idx : min(idx + TIME_STEPS, len(df_test))] += 1
    if anomaly:
        test_anomalies[idx : min(idx + TIME_STEPS, len(df_test))] += 1
test_pred_ratio = np.divide(test_anomalies, test_seqs)
test_pred = test_pred_ratio >= 0.5
print("Number of anomalous samples: ", sum(test_pred))


accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  4724
# Number of anomalous samples:  4746
# accuracy: 90.56%
# precision: 50.06%
# recall: 88.20%
# f1: 63.87%

# %%
idx = 4690
evaluation_array = [(test_seqs - test_anomalies)[idx:idx+400],
                    test_anomalies[idx:idx+400],
                    test_seqs[idx:idx+400],
                    test_pred_ratio[idx:idx+400],
                    test_pred[idx:idx+400],
                    df_test_label["label"][idx:idx+400]]

df = pd.DataFrame(evaluation_array, dtype=float)
df.index = ['Normal', 'Anomaly', '#Seq', 'Pred(%)', 'Pred', 'GT']
df.style.background_gradient(cmap='summer', axis=1)
# Out:
# <style type="text/css">
# #T_51afd_row0_col0, #T_51afd_row0_col1, #T_51afd_row0_col2, #T_51afd_row0_col3, #T_51afd_row0_col4, #T_51afd_row0_col5, #T_51afd_row0_col6, #T_51afd_row0_col7, #T_51afd_row0_col8, #T_51afd_row0_col9, #T_51afd_row0_col10, #T_51afd_row0_col11, #T_51afd_row0_col12, #T_51afd_row0_col13, #T_51afd_row0_col14, #T_51afd_row0_col15, #T_51afd_row0_col16, #T_51afd_row0_col17, #T_51afd_row0_col18, #T_51afd_row0_col19, #T_51afd_row0_col20, #T_51afd_row0_col21, #T_51afd_row0_col22, #T_51afd_row0_col23, #T_51afd_row0_col24, #T_51afd_row0_col25, #T_51afd_row0_col26, #T_51afd_row0_col27, #T_51afd_row0_col28, #T_51afd_row0_col29, #T_51afd_row0_col30, #T_51afd_row0_col31, #T_51afd_row0_col32, #T_51afd_row0_col33, #T_51afd_row0_col34, #T_51afd_row0_col35, #T_51afd_row0_col36, #T_51afd_row0_col37, #T_51afd_row0_col38, #T_51afd_row0_col39, #T_51afd_row0_col40, #T_51afd_row0_col41, #T_51afd_row0_col42, #T_51afd_row0_col43, #T_51afd_row0_col44, #T_51afd_row0_col45, #T_51afd_row0_col46, #T_51afd_row0_col47, #T_51afd_row0_col48, #T_51afd_row0_col49, #T_51afd_row0_col50, #T_51afd_row0_col51, #T_51afd_row0_col52, #T_51afd_row0_col53, #T_51afd_row0_col54, #T_51afd_row0_col55, #T_51afd_row0_col56, #T_51afd_row0_col57, #T_51afd_row0_col58, #T_51afd_row0_col59, #T_51afd_row0_col60, #T_51afd_row0_col61, #T_51afd_row0_col62, #T_51afd_row0_col63, #T_51afd_row0_col64, #T_51afd_row0_col65, #T_51afd_row0_col66, #T_51afd_row0_col67, #T_51afd_row0_col68, #T_51afd_row0_col69, #T_51afd_row0_col70, #T_51afd_row0_col71, #T_51afd_row0_col72, #T_51afd_row0_col73, #T_51afd_row0_col74, #T_51afd_row0_col75, #T_51afd_row0_col76, #T_51afd_row0_col77, #T_51afd_row0_col78, #T_51afd_row0_col79, #T_51afd_row0_col80, #T_51afd_row0_col81, #T_51afd_row0_col82, #T_51afd_row0_col83, #T_51afd_row0_col84, #T_51afd_row0_col85, #T_51afd_row0_col86, #T_51afd_row0_col87, #T_51afd_row0_col88, #T_51afd_row0_col89, #T_51afd_row0_col90, #T_51afd_row0_col91, #T_51afd_row0_col92, #T_51afd_row0_col93, #T_51afd_row0_col94, #T_51afd_row0_col95, #T_51afd_row0_col96, #T_51afd_row0_col97, #T_51afd_row0_col98, #T_51afd_row0_col99, #T_51afd_row0_col100, #T_51afd_row0_col101, #T_51afd_row0_col102, #T_51afd_row0_col103, #T_51afd_row0_col104, #T_51afd_row0_col105, #T_51afd_row0_col106, #T_51afd_row0_col107, #T_51afd_row0_col108, #T_51afd_row0_col109, #T_51afd_row0_col110, #T_51afd_row0_col111, #T_51afd_row0_col112, #T_51afd_row0_col113, #T_51afd_row0_col114, #T_51afd_row0_col115, #T_51afd_row0_col116, #T_51afd_row0_col117, #T_51afd_row0_col118, #T_51afd_row0_col119, #T_51afd_row0_col120, #T_51afd_row0_col121, #T_51afd_row0_col122, #T_51afd_row0_col123, #T_51afd_row0_col124, #T_51afd_row0_col125, #T_51afd_row0_col126, #T_51afd_row0_col127, #T_51afd_row0_col128, #T_51afd_row0_col129, #T_51afd_row0_col130, #T_51afd_row0_col131, #T_51afd_row0_col132, #T_51afd_row0_col133, #T_51afd_row0_col134, #T_51afd_row0_col135, #T_51afd_row0_col136, #T_51afd_row0_col137, #T_51afd_row0_col138, #T_51afd_row0_col139, #T_51afd_row0_col140, #T_51afd_row0_col141, #T_51afd_row0_col142, #T_51afd_row0_col143, #T_51afd_row0_col144, #T_51afd_row0_col145, #T_51afd_row0_col146, #T_51afd_row0_col147, #T_51afd_row0_col148, #T_51afd_row0_col149, #T_51afd_row0_col150, #T_51afd_row0_col151, #T_51afd_row0_col152, #T_51afd_row0_col153, #T_51afd_row0_col154, #T_51afd_row0_col155, #T_51afd_row0_col156, #T_51afd_row0_col157, #T_51afd_row0_col158, #T_51afd_row0_col159, #T_51afd_row0_col160, #T_51afd_row0_col161, #T_51afd_row0_col162, #T_51afd_row0_col163, #T_51afd_row0_col164, #T_51afd_row0_col165, #T_51afd_row0_col166, #T_51afd_row0_col167, #T_51afd_row0_col168, #T_51afd_row0_col169, #T_51afd_row0_col170, #T_51afd_row0_col171, #T_51afd_row0_col172, #T_51afd_row0_col173, #T_51afd_row0_col174, #T_51afd_row0_col175, #T_51afd_row0_col176, #T_51afd_row0_col177, #T_51afd_row0_col178, #T_51afd_row0_col179, #T_51afd_row0_col180, #T_51afd_row0_col181, #T_51afd_row0_col182, #T_51afd_row0_col183, #T_51afd_row0_col184, #T_51afd_row0_col185, #T_51afd_row0_col1 ...

# %% [markdown]
# ### #3 we could find the threshold with highest f1 score by calculating all cases

# %%
from evaluator import evaluate

label = create_sequences(df_test_label["label"], TIME_STEPS)
print(label.shape)
scores = evaluate(x_test, x_test_pred, label, n=10, scoring="abs_mean")
# Out:
# (28380, 100)

# %%
# print("f1:",np.max(scores['f1']))
idx = np.argmax(scores["f1"])

print(f"threshold: {scores['thresholds'][idx]}")
print(f"precision: {scores['precision'][idx]*100:.2f}%")
print(f"recall: {scores['recall'][idx]*100:.2f}%")
print(f"f1: {scores['f1'][idx]*100:.2f}%")
# Out:
# threshold: 0.0
# precision: 12.28%
# recall: 100.00%
# f1: 21.88%
