# %% [markdown]
# ## Introduction
#
# This script demonstrates how you can use a RNN-based model to detect anomalies in timeseries data.

# %% [markdown]
# ## Setup

# %%
import os
import random

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import backend as K
from sklearn.preprocessing import StandardScaler
from tqdm.notebook import tqdm

from evaluator import evaluate, compute_threshold
from dataloader import loader


os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# 2023-03-23 15:37:25.711617: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# # Load the data

# %%
df_train, df_test, df_test_label = loader(dataset="SMAP")

# %% [markdown]
# ## Prepare training data

# %%
# Skip data normalization because SMAP datas were already normalized.
df_train = df_train.fillna(method="ffill")
scaler = StandardScaler()
scaler.fit(df_train)
df_training_value = pd.DataFrame(scaler.transform(df_train))
df_test_value = pd.DataFrame(scaler.transform(df_test))
print("Number of training samples:", len(df_training_value))
print("Number of training samples:", len(df_test_value))
# Out:
# Number of training samples: 135183
# Number of training samples: 427617

# %% [markdown]
# ### Create sequences
# Create sequences combining `TIME_STEPS` contiguous data values from the
# training data.

# %%
TIME_STEPS = 100


# Generated training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)

# Create sequences from test values.
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)
# Out:
# Training input shape:  (135084, 100, 25)
# Test input shape:  (427518, 100, 25)

# %% [markdown]
# ## Build a model

# %%
class Generator(keras.Model):
    def __init__(self, time_step, x_dim, h1_dim, h2_dim, name="generator", **kwargs):
        super(Generator, self).__init__(name=name, **kwargs)
        self.generator_inputs = keras.Input(shape=(time_step, x_dim))
        self.generator_lstm1 = layers.LSTM(h1_dim, dropout=0.2, return_sequences="True")
        self.generator_lstm2 = layers.LSTM(h2_dim)
        self.generator_repeat = layers.RepeatVector(time_step)
        self.generator_lstm3 = layers.LSTM(h2_dim, dropout=0.2, return_sequences="True")
        self.generator_lstm4 = layers.LSTM(h1_dim)
        self.generator_dense = layers.Dense(time_step * x_dim)
        self.reshape = layers.Reshape([time_step, x_dim])

    def call(self, inputs):
        self.generator_inputs = inputs
        hidden1 = self.generator_lstm1(self.generator_inputs)
        hidden2 = self.generator_lstm2(hidden1)
        repeat = self.generator_repeat(hidden2)
        hidden3 = self.generator_lstm3(repeat)
        hidden4 = self.generator_lstm4(hidden3)
        flatten = self.generator_dense(hidden4)
        generated_x = self.reshape(flatten)

        return generated_x

# %%
class Discriminator(keras.Model):
    def __init__(self, time_step, x_dim, h_dim, name="discriminator", **kwargs):
        super(Discriminator, self).__init__(name=name, **kwargs)
        self.discriminator_inputs = keras.Input(shape=(time_step, x_dim))
        self.discriminator_lstm1 = layers.LSTM(h_dim, dropout=0.2, return_sequences="True")
        self.discriminator_lstm2 = layers.LSTM(h_dim, dropout=0.2)
        self.discriminator_dense = layers.Dense(1, activation="sigmoid")

    def call(self, inputs):
        self.discriminator_inputs = inputs
        hidden1 = self.discriminator_lstm1(self.discriminator_inputs)
        hidden2 = self.discriminator_lstm2(hidden1)
        result = self.discriminator_dense(hidden2)

        return result

# %%
generator = Generator(TIME_STEPS, x_train.shape[2], 128, 64, dtype="float32")
discriminator = Discriminator(TIME_STEPS, x_train.shape[2], 64, dtype="float32")

gan = keras.models.Sequential([generator, discriminator])

discriminator.compile(loss="binary_crossentropy", optimizer="adam")
discriminator.trainable = False
gan.compile(loss="binary_crossentropy", optimizer="adam")
# Out:
# 2023-03-23 15:37:29.270675: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-03-23 15:37:29.311487: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-23 15:37:29.311522: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-03-23 15:37:29.314310: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-03-23 15:37:29.314383: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-03-23 15:37:29.315258: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-03-23 15:37:29.315524: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-03-23 15:37:29.316283: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-03-23 15:37:29.316923: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-03-23 15:37:29.317081: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-03-23 15:37:29.317995: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-23 15:37:29.318383: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-23 15:37:29.321036: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:1f:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2023-03-23 15:37:29.321549: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-03-23 15:37:29.321582: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-03-23 15:37:29.798638: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-03-23 15:37:29.798668: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-03-23 15:37:29.798674: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-03-23 15:37:29.799670: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-03-23 15:37:29.799702: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22312 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:1f:00.0, compute capability: 8.6)

# %% [markdown]
# ## Train the model

# %%
# Function for training GAN
# Ref: https://github.com/young-eun-nam/Mr.TAD/blob/main/Baseline%20-%20LSTM-GAN.ipynb
def train_gan(gan, dataset, batch_size, codings_size, dim, n_epochs=50):
    generator, discriminator = gan.layers
    for epoch in tqdm(range(n_epochs)):
        for X_batch in dataset:
            noise = tf.random.normal(shape=[batch_size, codings_size, dim])
            generated_images = generator(noise)
            X_fake_and_real = tf.concat([generated_images, X_batch], axis=0)
            y1 = tf.constant([[0.]] * batch_size + [[1.]] * batch_size)
            discriminator.trainable = True
            discriminator.train_on_batch(X_fake_and_real, y1)
            noise = tf.random.normal(shape=[batch_size, codings_size, dim])
            y2 = tf.constant([[1.]] * batch_size)
            discriminator.trainable = False
            gan.train_on_batch(noise, y2)

# %%
dataset = tf.data.Dataset.from_tensor_slices(x_train)
dataset = dataset.batch(128, drop_remainder=True).prefetch(1)

train_gan(gan, dataset, 128, x_train.shape[1], x_train.shape[2])
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# 2023-03-23 15:37:32.283734: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-03-23 15:37:32.908394: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2023-03-23 15:37:33.068139: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-03-23 15:37:33.628930: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-03-23 15:37:33.628999: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-03-23 15:37:34.787909: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-03-23 15:37:34.816396: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2900000000 Hz

# %% [markdown]
# ## Detecting anomalies
# ### We could set threshold my using train loss, and detect which points are anomalies

# %%
# Get prediction of train data
x_train_pred = gan.layers[0].predict(x_train)
print("Predict train data done")

# Get test MAE loss.
x_test_pred = gan.layers[0].predict(x_test)
print("Predict test data done")
# Out:
# Predict train data done
# Predict test data done

# %%
thresholds = {
    "abs_mean": compute_threshold(x_train, x_train_pred, option="abs_mean"),
    "abs_median": compute_threshold(x_train, x_train_pred, option="abs_median"),
    "abs_max": compute_threshold(x_train, x_train_pred, option="abs_max"),
    "square_mean": compute_threshold(x_train, x_train_pred, option="square_mean"),
    "square_median": compute_threshold(x_train, x_train_pred, option="square_median"),
    "rank": compute_threshold(x_train, x_train_pred, option="rank", label=df_test_label["label"]),
}
print(f'abs mean threshold: {thresholds["abs_mean"]:.3f}')
print(f'abs median threshold: {thresholds["abs_median"]:.3f}')
print(f'abs max threshold: {thresholds["abs_max"]:.3f}')
print(f'square mean threshold: {thresholds["square_mean"]:.3f}')
print(f'square median threshold: {thresholds["square_median"]:.3f}')
print(f'rank threshold: {thresholds["rank"]:.3f}')

# Detect all the samples which are anomalies.
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
# Out:
# abs mean threshold: 22.270
# abs median threshold: 21.988
# abs max threshold: 239.442
# square mean threshold: 161.825
# square median threshold: 149.212
# rank threshold: 22.405

# %%
# Choose the lowest loss of the anomaly datas((# of anomalies)th) as threshold by using rank option
threshold = thresholds["rank"]
print(f"threshold: {threshold:.3f}")

fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)

labels = df_test_label["label"].values.tolist()
dates = df_test.index


pd.DataFrame(np.sum(test_mae_loss, axis=1)).plot(ax=ax)
pd.DataFrame([threshold] * len(df_test)).plot(ax=ax)
ax.legend(["reconstruction error", "threshold"], loc="upper right")


temp_start = dates[0]
temp_date = dates[0]
temp_label = labels[0]

for xc, value in zip(dates, labels):
    if temp_label != value:
        if temp_label == True:
            ax.axvspan(temp_start, temp_date, alpha=0.2, color="orange")
        temp_start = xc
        temp_label = value
    temp_date = xc
if temp_label == True:
    ax.axvspan(temp_start, xc, alpha=0.2, color="orange")
# Out:
# threshold: 22.405

# %% [markdown]
# ## Predict & Evaluation

# %% [markdown]
# ## #1 if any included time step has anomalies => abnormal

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalies = np.sum(test_mae_loss, axis=1) > threshold
print("Number of anomaly samples: ", np.sum(anomalies))

anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.any(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)
print("Number of anomalous samples: ", len(anomalous_data_indices))

test_pred = np.zeros(len(df_test))
test_label = df_test_label["label"]
test_pred[anomalous_data_indices] = 1

accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  121314
# Number of anomalous samples:  218819
# accuracy: 44.48%
# precision: 8.25%
# recall: 33.01%
# f1: 13.20%

# %% [markdown]
# ## #2 If half of included time steps has anomaly => abnormal

# %%
# data i is an anomaly if ratio of anomalies sequences/involved total sequences >= 0.5
anomalies = np.sum(test_mae_loss, axis=1) > threshold
test_anomalies = np.zeros(len(df_test))
test_seqs = np.zeros(len(df_test))
test_label = df_test_label["label"]
print("Number of anomaly samples: ", np.sum(anomalies))

for idx, anomaly in enumerate(anomalies):
    test_seqs[idx : min(idx + TIME_STEPS, len(df_test))] += 1
    if anomaly:
        test_anomalies[idx : min(idx + TIME_STEPS, len(df_test))] += 1
test_pred_ratio = np.divide(test_anomalies, test_seqs)
test_pred = test_pred_ratio >= 0.5
print("Number of anomalous samples: ", sum(test_pred))


accuracy = (np.sum(test_pred == test_label)) / len(test_label)
precision = (np.sum(test_pred * test_label)) / np.sum(test_pred)
recall = (np.sum(test_pred * test_label)) / np.sum(test_label)
f1 = 2 * (precision * recall) / (precision + recall + 1e-7)

print(f"accuracy: {accuracy*100:.2f}%")
print(f"precision: {precision*100:.2f}%")
print(f"recall: {recall*100:.2f}%")
print(f"f1: {f1*100:.2f}%")
# Out:
# Number of anomaly samples:  121314
# Number of anomalous samples:  127728
# accuracy: 62.21%
# precision: 8.16%
# recall: 19.06%
# f1: 11.43%

# %%
idx = 4690
evaluation_array = [(test_seqs - test_anomalies)[idx:idx+400],
                    test_anomalies[idx:idx+400],
                    test_seqs[idx:idx+400],
                    test_pred_ratio[idx:idx+400],
                    test_pred[idx:idx+400],
                    df_test_label["label"][idx:idx+400]]

df = pd.DataFrame(evaluation_array, dtype=float)
df.index = ['Normal', 'Anomaly', '#Seq', 'Pred(%)', 'Pred', 'GT']
df.style.background_gradient(cmap='summer', axis=1)
# Out:
# <style type="text/css">
# #T_bd503_row0_col0, #T_bd503_row1_col212, #T_bd503_row1_col213, #T_bd503_row1_col214, #T_bd503_row1_col215, #T_bd503_row1_col216, #T_bd503_row1_col217, #T_bd503_row1_col218, #T_bd503_row1_col219, #T_bd503_row1_col220, #T_bd503_row1_col221, #T_bd503_row1_col222, #T_bd503_row1_col223, #T_bd503_row1_col224, #T_bd503_row1_col225, #T_bd503_row2_col0, #T_bd503_row2_col1, #T_bd503_row2_col2, #T_bd503_row2_col3, #T_bd503_row2_col4, #T_bd503_row2_col5, #T_bd503_row2_col6, #T_bd503_row2_col7, #T_bd503_row2_col8, #T_bd503_row2_col9, #T_bd503_row2_col10, #T_bd503_row2_col11, #T_bd503_row2_col12, #T_bd503_row2_col13, #T_bd503_row2_col14, #T_bd503_row2_col15, #T_bd503_row2_col16, #T_bd503_row2_col17, #T_bd503_row2_col18, #T_bd503_row2_col19, #T_bd503_row2_col20, #T_bd503_row2_col21, #T_bd503_row2_col22, #T_bd503_row2_col23, #T_bd503_row2_col24, #T_bd503_row2_col25, #T_bd503_row2_col26, #T_bd503_row2_col27, #T_bd503_row2_col28, #T_bd503_row2_col29, #T_bd503_row2_col30, #T_bd503_row2_col31, #T_bd503_row2_col32, #T_bd503_row2_col33, #T_bd503_row2_col34, #T_bd503_row2_col35, #T_bd503_row2_col36, #T_bd503_row2_col37, #T_bd503_row2_col38, #T_bd503_row2_col39, #T_bd503_row2_col40, #T_bd503_row2_col41, #T_bd503_row2_col42, #T_bd503_row2_col43, #T_bd503_row2_col44, #T_bd503_row2_col45, #T_bd503_row2_col46, #T_bd503_row2_col47, #T_bd503_row2_col48, #T_bd503_row2_col49, #T_bd503_row2_col50, #T_bd503_row2_col51, #T_bd503_row2_col52, #T_bd503_row2_col53, #T_bd503_row2_col54, #T_bd503_row2_col55, #T_bd503_row2_col56, #T_bd503_row2_col57, #T_bd503_row2_col58, #T_bd503_row2_col59, #T_bd503_row2_col60, #T_bd503_row2_col61, #T_bd503_row2_col62, #T_bd503_row2_col63, #T_bd503_row2_col64, #T_bd503_row2_col65, #T_bd503_row2_col66, #T_bd503_row2_col67, #T_bd503_row2_col68, #T_bd503_row2_col69, #T_bd503_row2_col70, #T_bd503_row2_col71, #T_bd503_row2_col72, #T_bd503_row2_col73, #T_bd503_row2_col74, #T_bd503_row2_col75, #T_bd503_row2_col76, #T_bd503_row2_col77, #T_bd503_row2_col78, #T_bd503_row2_col79, #T_bd503_row2_col80, #T_bd503_row2_col81, #T_bd503_row2_col82, #T_bd503_row2_col83, #T_bd503_row2_col84, #T_bd503_row2_col85, #T_bd503_row2_col86, #T_bd503_row2_col87, #T_bd503_row2_col88, #T_bd503_row2_col89, #T_bd503_row2_col90, #T_bd503_row2_col91, #T_bd503_row2_col92, #T_bd503_row2_col93, #T_bd503_row2_col94, #T_bd503_row2_col95, #T_bd503_row2_col96, #T_bd503_row2_col97, #T_bd503_row2_col98, #T_bd503_row2_col99, #T_bd503_row2_col100, #T_bd503_row2_col101, #T_bd503_row2_col102, #T_bd503_row2_col103, #T_bd503_row2_col104, #T_bd503_row2_col105, #T_bd503_row2_col106, #T_bd503_row2_col107, #T_bd503_row2_col108, #T_bd503_row2_col109, #T_bd503_row2_col110, #T_bd503_row2_col111, #T_bd503_row2_col112, #T_bd503_row2_col113, #T_bd503_row2_col114, #T_bd503_row2_col115, #T_bd503_row2_col116, #T_bd503_row2_col117, #T_bd503_row2_col118, #T_bd503_row2_col119, #T_bd503_row2_col120, #T_bd503_row2_col121, #T_bd503_row2_col122, #T_bd503_row2_col123, #T_bd503_row2_col124, #T_bd503_row2_col125, #T_bd503_row2_col126, #T_bd503_row2_col127, #T_bd503_row2_col128, #T_bd503_row2_col129, #T_bd503_row2_col130, #T_bd503_row2_col131, #T_bd503_row2_col132, #T_bd503_row2_col133, #T_bd503_row2_col134, #T_bd503_row2_col135, #T_bd503_row2_col136, #T_bd503_row2_col137, #T_bd503_row2_col138, #T_bd503_row2_col139, #T_bd503_row2_col140, #T_bd503_row2_col141, #T_bd503_row2_col142, #T_bd503_row2_col143, #T_bd503_row2_col144, #T_bd503_row2_col145, #T_bd503_row2_col146, #T_bd503_row2_col147, #T_bd503_row2_col148, #T_bd503_row2_col149, #T_bd503_row2_col150, #T_bd503_row2_col151, #T_bd503_row2_col152, #T_bd503_row2_col153, #T_bd503_row2_col154, #T_bd503_row2_col155, #T_bd503_row2_col156, #T_bd503_row2_col157, #T_bd503_row2_col158, #T_bd503_row2_col159, #T_bd503_row2_col160, #T_bd503_row2_col161, #T_bd503_row2_col162, #T_bd503_row2_col163, #T_bd503_row2_col164, #T_bd503_row2_col165, #T_bd503_row2_col166, #T_bd503_row2_col167, #T_bd503_row2_col168, #T_bd503_row2_col169, #T_bd503_row2_col170, #T_bd503_row2_col171 ...

# %% [markdown]
# ### #3 we could find the threshold with highest f1 score by calculating all cases

# %%
from evaluator import evaluate

label = create_sequences(df_test_label["label"], TIME_STEPS)
print(label.shape)
scores = evaluate(x_test, x_test_pred, label, n=10, scoring="abs_mean")
# Out:
# (427518, 100)

# %%
# print("f1:",np.max(scores['f1']))
idx = np.argmax(scores["f1"])

print(f"threshold: {scores['thresholds'][idx]}")
print(f"precision: {scores['precision'][idx]*100:.2f}%")
print(f"recall: {scores['recall'][idx]*100:.2f}%")
print(f"f1: {scores['f1'][idx]*100:.2f}%")
# Out:
# threshold: 0.0
# precision: 14.35%
# recall: 100.00%
# f1: 25.09%
